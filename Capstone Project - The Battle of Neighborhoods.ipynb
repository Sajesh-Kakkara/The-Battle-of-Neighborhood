# %% [markdown]
#
#
#
# <a id='toc'></a>
# <center><h1>The Battle of Neighborhood</font></h1>
# Segmenting and Clustering Neighborhoods of Mumbai and Pune
# by Sajesh S Kakkara</center>
#
# ----

# %% [markdown]
# ## Table of Contents
# - [Introduction](#introduction)
# - [Objectives](#objective)
# - [Data](#data)
# - [Methodology](#methodology)
#     - [Analyze Mumbai](#analyzeKL)
#     - [K-mean Cluster Mumbai](#kmeankl)
#     - [Analyze Pune](#analyzeJB)
#     - [K-mean Cluster Pune](#kmeanjb)
# - [Results](#results)
# - [Discussion](#discussion)
# - [Conclusion](#conclusion)

# %% [markdown]
# <a id='Introduction'></a>
# # **Introduction**
# Mumbai and Pune are two major cities in India. Both cities become a center of attention for residential, job employment, tourism, education, shopping and sports activity. Both cities are well known in India, and become the top choice for local and foreign communities.
#
# Brief information about both cities:
#
# - **Mumbai:**  (/mʊmˈbaɪ/; also known as Bombay) is the capital city of the Indian state of Maharashtra. It is the most populous city in India with an estimated city proper population of 12.4 million as of 2011. Along with the neighbouring regions of the Mumbai Metropolitan Region, it is the second most populous metropolitan area in India, with a population of 21.3 million as of 2016. Mumbai lies on the Konkan coast on the west coast of India and has a deep natural harbour. In 2008, Mumbai was named an alpha world city. It is also the wealthiest city in India, and has the highest number of millionaires and billionaires among all cities in India.
# (*Source:* https://en.wikipedia.org/wiki/Mumbai)
#
# - **Pune:** (Marathi pronunciation: [puɳe]; English: /ˈpuːnə/;), formerly spelled Poona (1857–1978), is the second largest city in the Indian state of Maharashtra, after Mumbai. It is the ninth most populous city in the country with an estimated population of 3.13 million. Along with its Industrial twin Pimpri Chinchwad and the three cantonment towns of Pune, Khadki and Dehu Road, Pune forms the urban core of the eponymous Pune Metropolitan Region (PMR). According to the 2011 census, the urban area has a combined population of 5.05 million while the population of the metropolitan region is estimated at 7.27 million. Situated 560 metres (1,837 feet) above sea level on the Deccan plateau on the right bank of the Mutha river, Pune is also the administrative headquarters of its namesake district. In the 18th century, the city was the seat of the Peshwas, the prime ministers of the Maratha Empire and so was one of the most important political centres on the Indian subcontinent. Pune is ranked the No. 1 city in India in 'ease of living' ranking index. Pune is also a most important center for civil services training.
# (*Source:* https://en.wikipedia.org/wiki/Pune)

# %% [markdown]
# <a id='objective'></a>
# # **Objective**
# In this project, we will study in details the area classification using Foursquare data and machine learning segmentation and clustering.
# The aim of this project is to segment areas of Mumbai and Pune based on the most common places captured from Foursquare.
#
# Using segmentation and clustering, we hope we can determine:
# 1. The similarity or dissimilarirty of both cities
# 2. Classification of area located inside the city whether it is residential, tourism places, or others

# %% [markdown]
# <a id='data'></a>
# # **Data**
# The data acquired from wikipedia pages and restructure to csv file for easier manipulation and reading. Both files uploaded to my github for references. Link to the files are:
# - https://github.com/skakkara-in-ibm-com/Coursera_Capstone_Assignment1/blob/master/Mumbai_district.csv
# - https://github.com/skakkara-in-ibm-com/Coursera_Capstone_Assignment1/blob/master/Pune_district.csv
#
#
# Another aspect to consider for this project is the Foursquare data. I believe that the data as good as provided, meaning although we are using Foursquare data for segmentation and clustering, the amount and accuracy of data captured can't 100% determine correct classification in real world.
#
# To start, let's get and look at the data. I've already downloaded it, so let's read it (from local drive) and load it to dataframe:

# %%
# !pip install geocoder
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (2.18.4)
# Requirement already satisfied: future in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (0.16.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (1.11.0)
# Requirement already satisfied: click in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (6.7)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (2018.10.15)
# distributed 1.21.8 requires msgpack, which is not installed.
# Solving environment: done
#
# # All requested packages already installed.

# %%
#import the required library
import numpy as np
import pandas as pd
#read csv file contain Mumbai data
df_mum = pd.read_csv('Mumbai_district.csv')
df_mum.head()
# Out:
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#    Postcode District               Area  Taluka PostalStatus
# 0    400001   Mumbai         Bazargate   Mumbai   Sub Office
# 1    400001   Mumbai             M P T   Mumbai   Sub Office
# 2    400001   Mumbai    Stock Exchange   Mumbai   Sub Office
# 3    400001   Mumbai          Tajmahal   Mumbai   Sub Office
# 4    400001   Mumbai  Town Hall Mumbai   Mumbai   Sub Office

# %%
#examine data
print('Mumbai dataframe has {} district and {} areas.'.format(
        len(df_mum['Taluka'].unique()),
        df_mum.shape[0]
    )
)
#grouping data to find District with highest number of area
df_mum.groupby('Taluka').count()
# Out:
# Mumbai dataframe has 17 district and 242 areas.
#                    Postcode  District  Area  PostalStatus
# Taluka
# Bandra                    1         1     1             1
# Borivali East             5         5     5             5
# Borivali West             3         3     3             3
# Dahisar East              2         2     2             2
# Dahisar West              1         1     1             1
# Goregaon East             4         4     4             4
# Goregaon West             4         4     4             4
# Jogeshwari East           2         2     2             2
# Jogeshwari West           2         2     2             2
# Kandivali East            4         4     4             4
# Kandivali West            2         2     2             2
# Malad East                2         2     2             2
# Malad West                6         6     6             6
# Mumbai                  146       146   146           146
# Mumbai East              10        10    10            10
# Mumbai North East        47        47    47            47
# Mumbai South              1         1     1             1

# %%
#read and load JB data
df_pun = pd.read_csv("Pune_district.csv")
df_pun.head()
# Out:
#    Postcode District               Area Taluka   PostalStatus
# 0    410301     Pune          Khandala   Maval     Sub Office
# 1    410302     Pune  R P T S Khandala   Maval     Sub Office
# 2    410401     Pune          Ambavane   Maval  Branch Office
# 3    410401     Pune        Kusgaon Bk   Maval  Branch Office
# 4    410401     Pune    Lonavala Bazar   Maval     Sub Office

# %%
#examine
print('Pune dataframe has {} district and {} areas.'.format(
        len(df_pun['Taluka'].unique()),
        df_pun.shape[0]
    )
)
#group by district
df_pun.groupby('Taluka').count()
# Out:
# Pune dataframe has 17 district and 810 areas.
#                 Postcode  District  Area  PostalStatus
# Taluka
# Ambegaon              43        43    43            43
# Baramati              56        56    56            56
# Bhor                  69        69    69            69
# Daund                 51        51    51            51
# Haveli                80        80    80            80
# Indapur               50        50    50            50
# Junnar                68        68    68            68
# Khed                  68        68    68            68
# Maval                 43        43    43            43
# Mulshi                31        31    31            31
# Pune                   2         2     2             2
# Pune City            124       124   124           124
# Pune City East         1         1     1             1
# Pune Moffusil          2         2     2             2
# Purandar              55        55    55            55
# Shirur                52        52    52            52
# Velhe                 15        15    15            15

# %%
#now, using Geocoder and Google API, we get the Latitude and Longitude of each area
import geocoder
SSK_API_KEY='AIzaSyCGMWm7FNWp7zamQX-LJOjckjjvfb5MYxk'
#function to get latitude and longitude
def get_latlng(postal_code):
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.google('{}, India'.format(postal_code), key=SSK_API_KEY)
        #print(g)
        lat_lng_coords = g.latlng
    return lat_lng_coords

# %%
#put new column of latitude and logitude into dataframe
postal_codes_mum = df_mum['Taluka']+df_mum['Area']
coords = [ get_latlng(postal_code) for postal_code in postal_codes_mum.tolist() ]
df_mum_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df_mum['Latitude'] = df_mum_coords['Latitude']
df_mum['Longitude'] = df_mum_coords['Longitude']
df_mum.head(10)
# Out:
#    Postcode District               Area  Taluka PostalStatus   Latitude  \
# 0    400001   Mumbai         Bazargate   Mumbai   Sub Office  18.936518
# 1    400001   Mumbai             M P T   Mumbai   Sub Office  18.948288
# 2    400001   Mumbai    Stock Exchange   Mumbai   Sub Office  18.930012
# 3    400001   Mumbai          Tajmahal   Mumbai   Sub Office  18.921729
# 4    400001   Mumbai  Town Hall Mumbai   Mumbai   Sub Office  19.115063
# 5    400001   Mumbai      Mumbai G P O   Mumbai  Head Office  18.938956
# 6    400002   Mumbai         Kalbadevi   Mumbai  Head Office  18.948738
# 7    400002   Mumbai           Ramwadi   Mumbai   Sub Office  18.950313
# 8    400002   Mumbai         S C Court   Mumbai   Sub Office  18.931120
# 9    400002   Mumbai        Thakurdwar   Mumbai   Sub Office  18.949847
#
#    Longitude
# 0  72.835823
# 1  72.844163
# 2  72.833639
# 3  72.833031
# 4  72.850029
# 5  72.837057
# 6  72.828883
# 7  72.827458
# 8  72.830150
# 9  72.822745

# %%
#new column for Pune dataframe
postal_codes_pun = df_pun['Taluka']+df_pun['Area']
coords = [ get_latlng(postal_code) for postal_code in postal_codes_pun.tolist() ]
df_pun_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df_pun['Latitude'] = df_pun_coords['Latitude']
df_pun['Longitude'] = df_pun_coords['Longitude']
df_pun.head(10)
# Out:
#    Postcode District                   Area Taluka   PostalStatus   Latitude  \
# 0    410301     Pune              Khandala   Maval     Sub Office  18.755211
# 1    410302     Pune      R P T S Khandala   Maval     Sub Office  18.769203
# 2    410401     Pune              Ambavane   Maval  Branch Office  20.593684
# 3    410401     Pune            Kusgaon Bk   Maval  Branch Office  20.593684
# 4    410401     Pune        Lonavala Bazar   Maval     Sub Office  20.593684
# 5    410401     Pune              Lonavala   Maval     Sub Office  18.755211
# 6    410402     Pune  Ins Shivaji Lonavale   Maval     Sub Office  18.746499
# 7    410402     Pune              Kurwande   Maval  Branch Office  20.593684
# 8    410403     Pune          Kaivalyadham   Maval     Sub Office  18.760702
# 9    410405     Pune               Kamshet   Maval     Sub Office  18.755211
#
#    Longitude
# 0  73.444539
# 1  73.376764
# 2  78.962880
# 3  78.962880
# 4  78.962880
# 5  73.444539
# 6  73.399671
# 7  78.962880
# 8  73.415582
# 9  73.444539

# %% [markdown]
# Based on the data of Latitude and Longitude of both cities, we can now create map with pointed area in it.

# %%
from geopy.geocoders import Nominatim
import folium
address = 'Mumbai, India'
geolocator = Nominatim(user_agent='my-application')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
# create map of New York using latitude and longitude values
map_mum = folium.Map(location=[latitude, longitude], zoom_start=11)
# add markers to map
for lat, lng, borough, neighborhood in zip(df_mum['Latitude'], df_mum['Longitude'], df_mum['District'], df_mum['Area']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_mum)  
map_mum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Pune, India'
geolocator = Nominatim(user_agent='my-application')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
# create map of New York using latitude and longitude values
map_pun = folium.Map(location=[latitude, longitude], zoom_start=10)
# add markers to map
for lat, lng, borough, neighborhood in zip(df_pun['Latitude'], df_pun['Longitude'], df_pun['District'], df_pun['Area']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_pun)  
map_pun
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id='methodology'></a>
# # **Methodology**
# In this project, I will use the basic methodology as taught in Week 3 lab.
# - Above, we have done convert addresses into their equivalent latitude and longitude values.
# - Then we will use the Foursquare API to explore neighborhoods in both cities Mumbai and Pune
# - After that, explore function to get the most common venue categories in each neighborhood,
# - and then use this feature to group the neighborhoods into clusters
#
# K-means clustering algorithm will be use to complete this task. And also, the Folium library to visualize the neighborhoods in Mumbai and Pune and their emerging clusters.
#
# Based on dataframe analysis above, we found out that **Mumbai Taluka** in **Mumbai** and **Pune City Taluka** in **Pune** are both have the highest number of Taluka within it those district.

# %%
#slice the original dataframe and create a new dataframe of the Mumbai Taluka
bbintang = df_mum[df_mum['Taluka'] == 'Mumbai'].reset_index(drop=True)
#get the geographical coordinates of Mumbai Taluka, Mumbai
address = 'Mumbai, Mumbai'
geolocator = Nominatim(user_agent='my-application')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
# create map of Bukit Bintang using latitude and longitude values
map_bintang = folium.Map(location=[latitude, longitude], zoom_start=12)
# add markers to map
for lat, lng, label in zip(bbintang['Latitude'], bbintang['Longitude'], bbintang['Area']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bintang)  
map_bintang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#slice the original dataframe and create a new dataframe of the Iskandar
jdt = df_pun[df_pun['Taluka'] == 'Pune City'].reset_index(drop=True)
#get the geographical coordinates of Manhattan
address = 'Pune City, Pune'
geolocator = Nominatim(user_agent='my-application')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
# create map of Bukit Bintang using latitude and longitude values
map_jdt = folium.Map(location=[latitude, longitude], zoom_start=12)
# add markers to map
for lat, lng, label in zip(jdt['Latitude'], jdt['Longitude'], jdt['Area']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_jdt)  
map_jdt
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Using Foursquare API to get venues at surounding area of both Mumbai Taluka, Mumbai and Pune City, Pune area.

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
#Define Foursquare Credentials and Version
CLIENT_ID = 'CRJZGMWSBD4YHMBD3BRLEMLCJ555DFNOPLT33QVFQ4DIX0G5' # your Foursquare ID
CLIENT_SECRET = 'HCNGAD5NIVFMU45IBQRZ0BGREVRRGQUX1HLDHHUN20D3PEQI' # your Foursquare Secret
VERSION = '20180604'
#explore the first neighborhood in our dataframe
#Get the neighborhood's latitude and longitude values.
neighborhood_latitude = bbintang.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = bbintang.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = bbintang.loc[0, 'Area'] # neighborhood name
#get the top 100 venues that are in Bukit Bintang within a radius of 500 meters
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
#Send the GET request and examine the resutls
results = requests.get(url).json()
#borrow the get_category_type function from the Foursquare lab.
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
#clean the json and structure it into a pandas dataframe
venues = results['response']['groups'][0]['items']    
nearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]
# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print('{} venues were returned by Foursquare for Mumbai Taluka, Mumbai.'.format(nearby_venues.shape[0]))
nearby_venues.head()
# Out:
# 32 venues were returned by Foursquare for Mumbai Taluka, Mumbai.
#                       name          categories        lat        lng
# 0              Royal China  Chinese Restaurant  18.938715  72.832933
# 1          Town House Cafe                 Bar  18.938550  72.833464
# 2  Dakshin Bar And Kitchen  Seafood Restaurant  18.936489  72.837490
# 3             Ideal Corner   Indian Restaurant  18.934961  72.834050
# 4            Sher-E-Punjab   Indian Restaurant  18.937944  72.837853

# %%
#explore the first neighborhood in our dataframe
#Get the neighborhood's latitude and longitude values.
neighborhood_latitude = jdt.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = jdt.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = jdt.loc[0, 'Area'] # neighborhood name
#get the top 100 venues that are in Marble Hill within a radius of 500 meters
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
#Send the GET request and examine the resutls
results = requests.get(url).json()
#clean the json and structure it into a pandas dataframe
venues = results['response']['groups'][0]['items']    
nearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]
# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print('{} venues were returned by Foursquare for Pune City, Pune.'.format(nearby_venues.shape[0]))
nearby_venues.head()
# Out:
# 3 venues were returned by Foursquare for Pune City, Pune.
#               name         categories        lat        lng
# 0  Cafe Coffee Day        Coffee Shop  18.512372  73.928695
# 1   Deccan Harvest  Indian Restaurant  18.514183  73.927503
# 2  Barbeque Nation          BBQ Joint  18.517125  73.923614

# %%
#function to repeat the same process to all area
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Area', 
                  'Area Latitude', 
                  'Area Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
#run the above function on each neighborhood and create a new dataframe
bintang_venues = getNearbyVenues(names=bbintang['Area'],
                                   latitudes=bbintang['Latitude'],
                                   longitudes=bbintang['Longitude']
                                  )
#check the size of the resulting dataframe
print(bintang_venues.shape)
bintang_venues.head()
# Out:
# Bazargate
# M P T
# Stock Exchange
# Tajmahal
# Town Hall Mumbai
# Mumbai G P O
# Kalbadevi
# Ramwadi
# S C Court
# Thakurdwar
# Ambewadi Mumbai
# Charni Road
# Chaupati
# Girgaon
# Madhavbaug
# Opera House
# Asvini
# Colaba
# Holiday Camp
# V W T C
# Malabar Hill
# Bharat Nagar Mumbai
# Grant Road
# N S Patkar Marg
# S V Marg
# Tardeo
# Falkland Road
# J J Hospital
# Kamathipura
# M A Marg
# Mumbai Central
# Princess Dock
# Dockyard Road
# Mazgaon Dock
# Mazgaon Road
# Mazgaon
# V K Bhavan
# Agripada
# Bpc Jacob Circle
# Chinchpokli
# Haines Road
# Jacob Circle
# Chamarbaug
# Haffkin Institute
# Lal Baug
# Parel Naka
# Parel
# Delisle Road
# Dadar Colony
# Dadar
# Naigaon Mumbai
# Sewri
# Kapad Bazar
# Mahim Bazar
# Mahim East
# Mahim
# Mori Road
# Dharavi Road
# Dharavi
# Worli Naka
# Worli
# Matunga
# Central Building
# Churchgate
# Marine Lines
# Nariman Point
# New Yogakshema
# Chunabhatti
# Sion
# Nehru Nagar Mumbai
# New Prabhadevi Road
# Prabhadevi
# Cumballa Hill
# Cumballa Sea Face
# Dr Deshmukh Marg
# Gowalia Tank
# V J B Udyan
# Bhawani Shankar Rd
# Bhawani Shankar
# Gokhale Road Mumbai
# Ranade Road
# S V S Marg
# Shivaji Park Mumbai
# A I Staff Colony
# Santacruz P T Colony
# Century Mill
# Worli Colony
# Worli Police Camp
# Worli Sea Face
# Kidwai Nagar Mumbai
# Wadala Rs
# Wadala
# High Court Building Mumbai
# Mantralaya Mumbai
# Secretariate
# Cotton Exchange
# Kalachowki
# L B S N E Collage
# Reay Road
# Haji Ali
# Tulsiwadi
# Rajbhavan Mumbai
# Antop Hill
# B P T Colony
# C G S Colony
# Juhu
# Bandra West
# B N Bhavan
# Bandra East
# Government Colony
# Kherwadi
# Danda
# Khar Colony
# Khar Delivery
# V P Road
# Andheri
# Azad Nagar Mumbai
# Santacruz Central
# Santacruz West
# Santacruz East
# Vakola
# Irla
# Vileparle West
# Hanuman Road
# Vileeparle East
# Vileparle Railway Station
# Andheri Railway Station
# H M P School
# J B Nagar
# Marol Bazar
# Marol Naka
# Madh
# Vesava
# Kandivali Rs
# Andheri East
# Nagardas Road
# Kurla
# Netajinagar
# Nitie
# Chakala Midc
# Seepz
# Vidyanagari
# Airport Mumbai
# International Airport
# Sahar P T Colony
# Sahargaon
# (2101, 7)
#          Area  Area Latitude  Area Longitude                    Venue  \
# 0  Bazargate       18.936518       72.835823              Royal China
# 1  Bazargate       18.936518       72.835823          Town House Cafe
# 2  Bazargate       18.936518       72.835823  Dakshin Bar And Kitchen
# 3  Bazargate       18.936518       72.835823             Ideal Corner
# 4  Bazargate       18.936518       72.835823            Sher-E-Punjab
#
#    Venue Latitude  Venue Longitude      Venue Category
# 0       18.938715        72.832933  Chinese Restaurant
# 1       18.938550        72.833464                 Bar
# 2       18.936489        72.837490  Seafood Restaurant
# 3       18.934961        72.834050   Indian Restaurant
# 4       18.937944        72.837853   Indian Restaurant

# %%
#run the above function on each neighborhood and create a new dataframe
jdt_venues = getNearbyVenues(names=jdt['Area'],
                                   latitudes=jdt['Latitude'],
                                   longitudes=jdt['Longitude']
                                  )
#check the size of the resulting dataframe
print(jdt_venues.shape)
jdt_venues.head()
# Out:
# C D A O
# Dr B A Chowk
# Ghorpuri Bazar
# N W College
# Pune Cantt East
# Pune
# Pune New Bazar
# Sachapir Street
# Bajirao Road
# Kapad Ganj
# Nana Peth
# Pune City
# Raviwar Peth
# Shukrawar Peth Pune
# Ammunition Factory Khadki
# East Khadki
# H E Factory
# Khadki Bazar
# Khadki
# A R Shala
# Deccan Gymkhana
# Film Institute
# Congress House Road
# S S C Exam Board
# Shivajinagar Pune
# Yerwada
# Yerwada T S
# Aundh T S
# Ganeshkhind
# Baner Road
# N C L Pune
# Baner Pashan Link Road
# Pride Platinum Baner
# Parvati Gaon
# Parvati
# Kasba Peth
# Mangalwar Peth Pune
# Rasta Peth
# Dapodi Bazar
# Dapodi
# Hadpsar I E
# 9 Drd
# Dukirkline
# Vadgaon Sheri
# Dhanori
# Dighi Camp
# Vishrantwadi
# Govt Polytechnic
# Model Colony
# Shivaji Housing Society
# Kalewadi
# Pimpri Colony
# Pimpri Waghire
# Masulkar Colony
# Nehrunagar Pune
# Pimpri P F
# Chinchwad East
# M Phulenagar
# Botanical Garden Pune
# Range Hills
# Armament
# Srpf
# N D A Khadakwasla
# Khadakwasla R S
# Bhosari I E
# Indrayaninagar
# Sangavi
# Pimple Saudagar
# Kunal Icon Pimple Saudagar
# Roseland Residency Pimple Saudagar
# Hadapsar
# Sasanenagar
# Lokmanyanagar
# Narayan Peth
# Rashtra Bhasha Bhavan
# S P College
# Sadashiv Peth
# Shaniwar Peth Pune
# C M E
# Airport Pune
# Iaf Station
# Vidyanagar Pune
# Chinchwadgaon
# Punawale
# Thathawade
# Thergaon
# Kasarwadi
# Akurdi
# Mundhva Av
# Mundhva
# Bibvewadi
# Market Yard Pune
# Salisbury Park
# T V Nagar
# Bhusari Colony
# Ex Serviceman Colony
# Kothrud
# Bhosarigoan
# Afmc
# Wanowarie
# Vadgaon Budruk
# Bhavani Peth
# Ghorpade Peth
# Guruwar Peth
# Swargate Chowk
# Swargate
# Dhankawadi
# P C N T
# Yamunanagar
# N I A
# Katraj
# Lohogaon
# Khondhwa Kh
# Kondhwa Bk
# Kondhwa Lh
# N I B M
# Anandnagar Pune
# Karvenagar
# Navsahyadri
# Wakad
# Warje
# Mohamadwadi
# Rupeenagar
# Talwade
# (911, 7)
#             Area  Area Latitude  Area Longitude              Venue  \
# 0       C D A O       18.515806       73.927164    Cafe Coffee Day
# 1       C D A O       18.515806       73.927164     Deccan Harvest
# 2       C D A O       18.515806       73.927164    Barbeque Nation
# 3  Dr B A Chowk       18.523306       73.869719      Coconut Grove
# 4  Dr B A Chowk       18.523306       73.869719  Mahesh Lunch Home
#
#    Venue Latitude  Venue Longitude      Venue Category
# 0       18.512372        73.928695         Coffee Shop
# 1       18.514183        73.927503   Indian Restaurant
# 2       18.517125        73.923614           BBQ Joint
# 3       18.525681        73.866989  Seafood Restaurant
# 4       18.520633        73.872360  Seafood Restaurant

# %%
#check how many venues were returned for each area
print('There are {} uniques categories in Mumbai.'.format(len(bintang_venues['Venue Category'].unique())))
bintang_venues.groupby('Area').count()
# Out:
# There are 178 uniques categories in Mumbai.
#                             Area Latitude  Area Longitude  Venue  \
# Area
# A I Staff Colony                        7               7      7
# Agripada                                6               6      6
# Airport Mumbai                          3               3      3
# Ambewadi Mumbai                        11              11     11
# Andheri                                 9               9      9
# Andheri East                            9               9      9
# Andheri Railway Station                11              11     11
# Antop Hill                              3               3      3
# Asvini                                  3               3      3
# Azad Nagar Mumbai                      19              19     19
# B N Bhavan                             31              31     31
# B P T Colony                            1               1      1
# Bandra East                            20              20     20
# Bandra West                            14              14     14
# Bazargate                              32              32     32
# Bharat Nagar Mumbai                    12              12     12
# Bhawani Shankar                         3               3      3
# Bhawani Shankar Rd                      3               3      3
# Bpc Jacob Circle                        8               8      8
# C G S Colony                            3               3      3
# Central Building                       13              13     13
# Century Mill                           14              14     14
# Chakala Midc                           17              17     17
# Chamarbaug                             16              16     16
# Charni Road                            29              29     29
# Chaupati                               50              50     50
# Chinchpokli                             4               4      4
# Chunabhatti                             5               5      5
# Churchgate                             50              50     50
# Colaba                                  3               3      3
# ...                                   ...             ...    ...
# Santacruz P T Colony                    7               7      7
# Santacruz West                         12              12     12
# Secretariate                           40              40     40
# Seepz                                  10              10     10
# Sewri                                   4               4      4
# Shivaji Park Mumbai                    42              42     42
# Sion                                   21              21     21
# Stock Exchange                         41              41     41
# Tajmahal                               49              49     49
# Tardeo                                  9               9      9
# Thakurdwar                              7               7      7
# Town Hall Mumbai                       10              10     10
# Tulsiwadi                              20              20     20
# V J B Udyan                             9               9      9
# V K Bhavan                             42              42     42
# V P Road                               15              15     15
# V W T C                                16              16     16
# Vakola                                 19              19     19
# Vesava                                  7               7      7
# Vidyanagari                            20              20     20
# Vileeparle East                        34              34     34
# Vileparle Railway Station              23              23     23
# Vileparle West                         19              19     19
# Wadala                                  6               6      6
# Wadala Rs                               4               4      4
# Worli                                   5               5      5
# Worli Colony                            5               5      5
# Worli Naka                             13              13     13
# Worli Police Camp                      12              12     12
# Worli Sea Face                          5               5      5
#
#                             Venue Latitude  Venue Longitude  Venue Category
# Area
# A I Staff Colony                         7                7               7
# Agripada                                 6                6               6
# Airport Mumbai                           3                3               3
# Ambewadi Mumbai                         11               11              11
# Andheri                                  9                9               9
# Andheri East                             9                9               9
# Andheri Railway Station                 11               11              11
# Antop Hill                               3                3               3
# Asvini                                   3                3               3
# Azad Nagar Mumbai                       19               19              19
# B N Bhavan                              31               31              31
# B P T Colony                             1                1               1
# Bandra East                             20               20              20
# Bandra West                             14               14              14
# Bazargate                               32               32              32
# Bharat Nagar Mumbai                     12               12              12
# Bhawani Shankar                          3                3               3
# Bhawani Shankar Rd                       3                3               3
# Bpc Jacob Circle                         8                8               8
# C G S Colony                             3                3               3
# Central Building                        13               13              13
# Century Mill                            14               14              14
# Chakala Midc                            17               17              17
# Chamarbaug                              16               16              16
# Charni Road                             29               29              29
# Chaupati                                50               50              50
# Chinchpokli                              4                4               4
# Chunabhatti                              5                5               5
# Churchgate                              50               50              50
# Colaba                                   3                3               3
# ...                                    ...              ...             ...
# Santacruz P T Colony                     7                7               7
# Santacruz West                          12               12              12
# Secretariate                            40               40              40
# Seepz                                   10               10              10
# Sewri                                    4                4               4
# Shivaji Park Mumbai                     42               42              42
# Sion                                    21               21              21
# Stock Exchange                          41               41              41
# Tajmahal                                49               49              49
# Tardeo                                   9                9               9
# Thakurdwar                               7                7               7
# Town Hall Mumbai                        10               10              10
# Tulsiwadi                               20               20              20
# V J B Udyan                              9                9               9
# V K Bhavan                              42               42              42
# V P Road                                15               15              15
# V W T C                                 16               16              16
# Vakola                                  19               19              19
# Vesava                                   7                7               7
# Vidyanagari                             20               20              20
# Vileeparle East                         34               34              34
# Vileparle Railway Station               23               23              23
# Vileparle West                          19               19              19
# Wadala                                   6                6               6
# Wadala Rs                                4                4               4
# Worli                                    5                5               5
# Worli Colony                             5                5               5
# Worli Naka                              13               13              13
# Worli Police Camp                       12               12              12
# Worli Sea Face                           5                5               5
#
# [143 rows x 6 columns]

# %%
#check how many venues were returned for each area
print('There are {} uniques categories in Pune.'.format(len(jdt_venues['Venue Category'].unique())))
jdt_venues.groupby('Area').count()
# Out:
# There are 129 uniques categories in Pune.
#                                      Area Latitude  Area Longitude  Venue  \
# Area
# 9 Drd                                            4               4      4
# A R Shala                                        4               4      4
# Afmc                                             3               3      3
# Airport Pune                                     9               9      9
# Akurdi                                           5               5      5
# Anandnagar Pune                                  6               6      6
# Armament                                         4               4      4
# Aundh T S                                        4               4      4
# Bajirao Road                                    24              24     24
# Baner Pashan Link Road                          11              11     11
# Baner Road                                      17              17     17
# Bhavani Peth                                     1               1      1
# Bhosari I E                                     13              13     13
# Bhosarigoan                                      5               5      5
# Bhusari Colony                                   8               8      8
# Bibvewadi                                        5               5      5
# Botanical Garden Pune                            3               3      3
# C D A O                                          3               3      3
# C M E                                           50              50     50
# Chinchwad East                                  21              21     21
# Chinchwadgaon                                   21              21     21
# Congress House Road                             15              15     15
# Dapodi                                           4               4      4
# Dapodi Bazar                                     5               5      5
# Deccan Gymkhana                                 53              53     53
# Dhankawadi                                       3               3      3
# Dhanori                                          1               1      1
# Dr B A Chowk                                     7               7      7
# East Khadki                                      2               2      2
# Ex Serviceman Colony                            18              18     18
# ...                                            ...             ...    ...
# Rasta Peth                                       8               8      8
# Raviwar Peth                                     7               7      7
# Roseland Residency Pimple Saudagar               9               9      9
# Rupeenagar                                       1               1      1
# S P College                                     30              30     30
# S S C Exam Board                                 4               4      4
# Sachapir Street                                 54              54     54
# Sadashiv Peth                                   16              16     16
# Salisbury Park                                   2               2      2
# Sasanenagar                                      5               5      5
# Shaniwar Peth Pune                              11              11     11
# Shivaji Housing Society                         20              20     20
# Shivajinagar Pune                                6               6      6
# Shukrawar Peth Pune                             11              11     11
# Swargate                                         4               4      4
# Swargate Chowk                                   4               4      4
# T V Nagar                                        4               4      4
# Talwade                                          1               1      1
# Thathawade                                       4               4      4
# Thergaon                                         5               5      5
# Vadgaon Budruk                                   1               1      1
# Vadgaon Sheri                                    2               2      2
# Vidyanagar Pune                                  3               3      3
# Vishrantwadi                                     8               8      8
# Wakad                                            4               4      4
# Wanowarie                                       20              20     20
# Warje                                            5               5      5
# Yamunanagar                                      4               4      4
# Yerwada                                          1               1      1
# Yerwada T S                                      4               4      4
#
#                                      Venue Latitude  Venue Longitude  \
# Area
# 9 Drd                                             4                4
# A R Shala                                         4                4
# Afmc                                              3                3
# Airport Pune                                      9                9
# Akurdi                                            5                5
# Anandnagar Pune                                   6                6
# Armament                                          4                4
# Aundh T S                                         4                4
# Bajirao Road                                     24               24
# Baner Pashan Link Road                           11               11
# Baner Road                                       17               17
# Bhavani Peth                                      1                1
# Bhosari I E                                      13               13
# Bhosarigoan                                       5                5
# Bhusari Colony                                    8                8
# Bibvewadi                                         5                5
# Botanical Garden Pune                             3                3
# C D A O                                           3                3
# C M E                                            50               50
# Chinchwad East                                   21               21
# Chinchwadgaon                                    21               21
# Congress House Road                              15               15
# Dapodi                                            4                4
# Dapodi Bazar                                      5                5
# Deccan Gymkhana                                  53               53
# Dhankawadi                                        3                3
# Dhanori                                           1                1
# Dr B A Chowk                                      7                7
# East Khadki                                       2                2
# Ex Serviceman Colony                             18               18
# ...                                             ...              ...
# Rasta Peth                                        8                8
# Raviwar Peth                                      7                7
# Roseland Residency Pimple Saudagar                9                9
# Rupeenagar                                        1                1
# S P College                                      30               30
# S S C Exam Board                                  4                4
# Sachapir Street                                  54               54
# Sadashiv Peth                                    16               16
# Salisbury Park                                    2                2
# Sasanenagar                                       5                5
# Shaniwar Peth Pune                               11               11
# Shivaji Housing Society                          20               20
# Shivajinagar Pune                                 6                6
# Shukrawar Peth Pune                              11               11
# Swargate                                          4                4
# Swargate Chowk                                    4                4
# T V Nagar                                         4                4
# Talwade                                           1                1
# Thathawade                                        4                4
# Thergaon                                          5                5
# Vadgaon Budruk                                    1                1
# Vadgaon Sheri                                     2                2
# Vidyanagar Pune                                   3                3
# Vishrantwadi                                      8                8
# Wakad                                             4                4
# Wanowarie                                        20               20
# Warje                                             5                5
# Yamunanagar                                       4                4
# Yerwada                                           1                1
# Yerwada T S                                       4                4
#
#                                      Venue Category
# Area
# 9 Drd                                             4
# A R Shala                                         4
# Afmc                                              3
# Airport Pune                                      9
# Akurdi                                            5
# Anandnagar Pune                                   6
# Armament                                          4
# Aundh T S                                         4
# Bajirao Road                                     24
# Baner Pashan Link Road                           11
# Baner Road                                       17
# Bhavani Peth                                      1
# Bhosari I E                                      13
# Bhosarigoan                                       5
# Bhusari Colony                                    8
# Bibvewadi                                         5
# Botanical Garden Pune                             3
# C D A O                                           3
# C M E                                            50
# Chinchwad East                                   21
# Chinchwadgaon                                    21
# Congress House Road                              15
# Dapodi                                            4
# Dapodi Bazar                                      5
# Deccan Gymkhana                                  53
# Dhankawadi                                        3
# Dhanori                                           1
# Dr B A Chowk                                      7
# East Khadki                                       2
# Ex Serviceman Colony                             18
# ...                                             ...
# Rasta Peth                                        8
# Raviwar Peth                                      7
# Roseland Residency Pimple Saudagar                9
# Rupeenagar                                        1
# S P College                                      30
# S S C Exam Board                                  4
# Sachapir Street                                  54
# Sadashiv Peth                                    16
# Salisbury Park                                    2
# Sasanenagar                                       5
# Shaniwar Peth Pune                               11
# Shivaji Housing Society                          20
# Shivajinagar Pune                                 6
# Shukrawar Peth Pune                              11
# Swargate                                          4
# Swargate Chowk                                    4
# T V Nagar                                         4
# Talwade                                           1
# Thathawade                                        4
# Thergaon                                          5
# Vadgaon Budruk                                    1
# Vadgaon Sheri                                     2
# Vidyanagar Pune                                   3
# Vishrantwadi                                      8
# Wakad                                             4
# Wanowarie                                        20
# Warje                                             5
# Yamunanagar                                       4
# Yerwada                                           1
# Yerwada T S                                       4
#
# [110 rows x 6 columns]

# %% [markdown]
# <a id='analyzeKL'></a>
# # Analyze Mumbai
# <div style="text-align: right">[Top](#toc)</div>

# %%
# one hot encoding
bintang_onehot = pd.get_dummies(bintang_venues[['Venue Category']], prefix="", prefix_sep="")
# add neighborhood column back to dataframe
bintang_onehot['Area'] = bintang_venues['Area'] 
# move neighborhood column to the first column
fixed_columns = [bintang_onehot.columns[-1]] + list(bintang_onehot.columns[:-1])
bintang_onehot = bintang_onehot[fixed_columns]
#examine the new dataframe size after one hot encoding
print('{} rows were returned after one hot encoding.'.format(bintang_onehot.shape[0]))
#group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
bintang_grouped = bintang_onehot.groupby('Area').mean().reset_index()
#examine the new dataframe size after one hot encoding
print('{} rows were returned after grouping.'.format(bintang_grouped.shape[0]))
# Out:
# 2101 rows were returned after one hot encoding.
# 143 rows were returned after grouping.

# %%
#print each neighborhood along with the top 5 most common venues
num_top_venues = 5
for hood in bintang_grouped['Area']:
    print("----"+hood+"----")
    temp = bintang_grouped[bintang_grouped['Area'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----A I Staff Colony ----
#                   venue  freq
# 0     Indian Restaurant  0.29
# 1           Bus Station  0.14
# 2             Multiplex  0.14
# 3  Fast Food Restaurant  0.14
# 4                   Pub  0.14
#
#
# ----Agripada ----
#                venue  freq
# 0             Bakery  0.33
# 1  Indian Restaurant  0.17
# 2        Coffee Shop  0.17
# 3                Gym  0.17
# 4         Restaurant  0.17
#
#
# ----Airport Mumbai ----
#                  venue  freq
# 0              Airport  0.67
# 1       Duty-free Shop  0.33
# 2          Music Venue  0.00
# 3  Monument / Landmark  0.00
# 4                Motel  0.00
#
#
# ----Ambewadi Mumbai ----
#                   venue  freq
# 0  Fast Food Restaurant  0.18
# 1             Juice Bar  0.18
# 2        Breakfast Spot  0.09
# 3    Italian Restaurant  0.09
# 4           Bus Station  0.09
#
#
# ----Andheri ----
#                            venue  freq
# 0                          Hotel  0.22
# 1              Indian Restaurant  0.22
# 2  Vegetarian / Vegan Restaurant  0.11
# 3               Department Store  0.11
# 4             Seafood Restaurant  0.11
#
#
# ----Andheri East ----
#                            venue  freq
# 0                          Hotel  0.22
# 1              Indian Restaurant  0.22
# 2  Vegetarian / Vegan Restaurant  0.11
# 3               Department Store  0.11
# 4             Seafood Restaurant  0.11
#
#
# ----Andheri Railway Station ----
#                   venue  freq
# 0     Indian Restaurant  0.18
# 1          Burger Joint  0.18
# 2  Fast Food Restaurant  0.09
# 3                Bakery  0.09
# 4            Food Court  0.09
#
#
# ----Antop Hill ----
#                      venue  freq
# 0        Convenience Store  0.33
# 1              Pizza Place  0.33
# 2            Historic Site  0.33
# 3                  Airport  0.00
# 4  New American Restaurant  0.00
#
#
# ----Asvini ----
#                      venue  freq
# 0      American Restaurant  0.33
# 1              Bus Station  0.33
# 2     Fast Food Restaurant  0.33
# 3                  Airport  0.00
# 4  New American Restaurant  0.00
#
#
# ----Azad Nagar Mumbai ----
#                venue  freq
# 0                Bar  0.16
# 1                Pub  0.16
# 2        Pizza Place  0.11
# 3  Indian Restaurant  0.11
# 4        Coffee Shop  0.11
#
#
# ----B N Bhavan ----
#                 venue  freq
# 0   Indian Restaurant  0.29
# 1  Seafood Restaurant  0.10
# 2          Irani Cafe  0.06
# 3  Chinese Restaurant  0.06
# 4                Café  0.06
#
#
# ----B P T Colony ----
#                              venue  freq
# 0                    Women's Store   1.0
# 1                          Airport   0.0
# 2                      Music Venue   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4              Monument / Landmark   0.0
#
#
# ----Bandra East ----
#                venue  freq
# 0  Indian Restaurant  0.25
# 1              Hotel  0.10
# 2        Pizza Place  0.10
# 3       Dessert Shop  0.05
# 4        Coffee Shop  0.05
#
#
# ----Bandra West ----
#                venue  freq
# 0               Café  0.21
# 1  Indian Restaurant  0.14
# 2     Sandwich Place  0.14
# 3             Lounge  0.14
# 4   Asian Restaurant  0.07
#
#
# ----Bazargate ----
#                 venue  freq
# 0   Indian Restaurant  0.28
# 1  Seafood Restaurant  0.09
# 2                Café  0.09
# 3  Chinese Restaurant  0.06
# 4          Irani Cafe  0.06
#
#
# ----Bharat Nagar Mumbai ----
#                 venue  freq
# 0      Ice Cream Shop  0.08
# 1              Lounge  0.08
# 2      Sandwich Place  0.08
# 3  Chinese Restaurant  0.08
# 4                 Bar  0.08
#
#
# ----Bhawani Shankar ----
#                venue  freq
# 0  Indian Restaurant  0.33
# 1              Plaza  0.33
# 2                Bar  0.33
# 3            Airport  0.00
# 4        Music Venue  0.00
#
#
# ----Bhawani Shankar Rd ----
#                venue  freq
# 0  Indian Restaurant  0.33
# 1              Plaza  0.33
# 2                Bar  0.33
# 3            Airport  0.00
# 4        Music Venue  0.00
#
#
# ----Bpc Jacob Circle ----
#                venue  freq
# 0  Indian Restaurant  0.25
# 1           Tea Room  0.12
# 2             Bakery  0.12
# 3                Spa  0.12
# 4                Gym  0.12
#
#
# ----C G S Colony ----
#                      venue  freq
# 0        Convenience Store  0.33
# 1              Pizza Place  0.33
# 2            Historic Site  0.33
# 3                  Airport  0.00
# 4  New American Restaurant  0.00
#
#
# ----Central Building ----
#                   venue  freq
# 0  Fast Food Restaurant  0.23
# 1      Department Store  0.15
# 2         Train Station  0.15
# 3        Ice Cream Shop  0.08
# 4         Movie Theater  0.08
#
#
# ----Century Mill ----
#                              venue  freq
# 0                           Lounge  0.14
# 1                     Noodle House  0.07
# 2               Athletics & Sports  0.07
# 3  Molecular Gastronomy Restaurant  0.07
# 4                             Café  0.07
#
#
# ----Chakala Midc ----
#                 venue  freq
# 0    Asian Restaurant  0.24
# 1               Diner  0.12
# 2   Indian Restaurant  0.12
# 3  Seafood Restaurant  0.12
# 4               Hotel  0.06
#
#
# ----Chamarbaug ----
#                  venue  freq
# 0    Indian Restaurant  0.25
# 1                Hotel  0.06
# 2  Sporting Goods Shop  0.06
# 3                 Park  0.06
# 4           Playground  0.06
#
#
# ----Charni Road ----
#                venue  freq
# 0          Juice Bar  0.10
# 1               Café  0.07
# 2         Restaurant  0.07
# 3  Indian Restaurant  0.07
# 4      Train Station  0.07
#
#
# ----Chaupati ----
#                   venue  freq
# 0     Indian Restaurant  0.12
# 1  Fast Food Restaurant  0.08
# 2        Ice Cream Shop  0.08
# 3             Juice Bar  0.06
# 4                  Café  0.06
#
#
# ----Chinchpokli ----
#                            venue  freq
# 0  Vegetarian / Vegan Restaurant  0.25
# 1                      Multiplex  0.25
# 2           Fast Food Restaurant  0.25
# 3                         Bakery  0.25
# 4                        Airport  0.00
#
#
# ----Chunabhatti ----
#             venue  freq
# 0  Breakfast Spot   0.2
# 1     Bus Station   0.2
# 2   Train Station   0.2
# 3   Metro Station   0.2
# 4     Event Space   0.2
#
#
# ----Churchgate ----
#                   venue  freq
# 0  Fast Food Restaurant  0.10
# 1        Ice Cream Shop  0.08
# 2                 Hotel  0.08
# 3    Italian Restaurant  0.06
# 4     Indian Restaurant  0.06
#
#
# ----Colaba ----
#                      venue  freq
# 0        Convenience Store  0.33
# 1         Asian Restaurant  0.33
# 2                      Bar  0.33
# 3                  Airport  0.00
# 4  New American Restaurant  0.00
#
#
# ----Cotton Exchange ----
#                              venue  freq
# 0                              Spa   1.0
# 1                          Airport   0.0
# 2                      Music Store   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4              Monument / Landmark   0.0
#
#
# ----Cumballa Hill ----
#                              venue  freq
# 0                              Spa   1.0
# 1                          Airport   0.0
# 2                      Music Store   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4              Monument / Landmark   0.0
#
#
# ----Cumballa Sea Face ----
#             venue  freq
# 0  Scenic Lookout   0.4
# 1      Smoke Shop   0.2
# 2          Arcade   0.2
# 3     Art Gallery   0.2
# 4     Music Store   0.0
#
#
# ----Dadar ----
#                venue  freq
# 0  Indian Restaurant  0.15
# 1      Movie Theater  0.12
# 2        Coffee Shop  0.08
# 3               Café  0.08
# 4              Hotel  0.04
#
#
# ----Dadar Colony ----
#                      venue  freq
# 0            Deli / Bodega  0.25
# 1                   Garden  0.25
# 2              Coffee Shop  0.25
# 3                     Café  0.25
# 4  New American Restaurant  0.00
#
#
# ----Danda ----
#                              venue  freq
# 0                              Spa   1.0
# 1                          Airport   0.0
# 2                      Music Store   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4              Monument / Landmark   0.0
#
#
# ----Delisle Road ----
#                            venue  freq
# 0  Vegetarian / Vegan Restaurant   0.2
# 1                            Spa   0.2
# 2                    Coffee Shop   0.2
# 3                      Multiplex   0.2
# 4           Fast Food Restaurant   0.2
#
#
# ----Dharavi ----
#                 venue  freq
# 0           Juice Bar  0.25
# 1         Coffee Shop  0.25
# 2                Café  0.25
# 3  Chinese Restaurant  0.25
# 4             Airport  0.00
#
#
# ----Dharavi Road ----
#            venue  freq
# 0         Garden  0.25
# 1          Diner  0.25
# 2  Train Station  0.25
# 3      Nightclub  0.25
# 4        Airport  0.00
#
#
# ----Dockyard Road ----
#                  venue  freq
# 0               Bakery  0.25
# 1  Government Building  0.12
# 2    Indian Restaurant  0.12
# 3    Convenience Store  0.12
# 4               Garden  0.12
#
#
# ----Dr Deshmukh Marg ----
#                   venue  freq
# 0             Racetrack  0.12
# 1        Sandwich Place  0.12
# 2                 Hotel  0.06
# 3                Bakery  0.06
# 4  Gym / Fitness Center  0.06
#
#
# ----Falkland Road ----
#                   venue  freq
# 0     Indian Restaurant  0.50
# 1           Snack Place  0.25
# 2  Fast Food Restaurant  0.25
# 3               Airport  0.00
# 4           Music Venue  0.00
#
#
# ----Girgaon ----
#                   venue  freq
# 0     Electronics Store  0.12
# 1  Fast Food Restaurant  0.12
# 2     Indian Restaurant  0.12
# 3             Juice Bar  0.12
# 4   Indie Movie Theater  0.06
#
#
# ----Gokhale Road Mumbai ----
#                   venue  freq
# 0    Seafood Restaurant  0.14
# 1  Fast Food Restaurant  0.14
# 2     Indian Restaurant  0.14
# 3     Convenience Store  0.14
# 4     Electronics Store  0.14
#
#
# ----Government Colony ----
#                 venue  freq
# 0   Indian Restaurant  0.29
# 1                 Bar  0.14
# 2  Chinese Restaurant  0.07
# 3              Bistro  0.07
# 4                Café  0.07
#
#
# ----Gowalia Tank ----
#                              venue  freq
# 0                              Spa   1.0
# 1                          Airport   0.0
# 2                      Music Store   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4              Monument / Landmark   0.0
#
#
# ----Grant Road ----
#                        venue  freq
# 0          Electronics Store  0.13
# 1                      Hotel  0.07
# 2                     Bakery  0.07
# 3                     Lounge  0.07
# 4  Middle Eastern Restaurant  0.07
#
#
# ----H M P School ----
#                venue  freq
# 0  Indian Restaurant  0.25
# 1       Burger Joint  0.25
# 2         Restaurant  0.12
# 3         Food Court  0.12
# 4             Bakery  0.12
#
#
# ----Haffkin Institute ----
#                venue  freq
# 0  Indian Restaurant  0.50
# 1         Playground  0.17
# 2        Coffee Shop  0.17
# 3     Farmers Market  0.17
# 4            Airport  0.00
#
#
# ----Haines Road ----
#                              venue  freq
# 0                              Spa   1.0
# 1                          Airport   0.0
# 2                      Music Store   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4              Monument / Landmark   0.0
#
#
# ----High Court Building Mumbai ----
#                   venue  freq
# 0     Indian Restaurant  0.19
# 1                  Café  0.08
# 2  Fast Food Restaurant  0.08
# 3           Coffee Shop  0.05
# 4    Seafood Restaurant  0.03
#
#
# ----Holiday Camp ----
#                            venue  freq
# 0                         Lounge   0.2
# 1              Indian Restaurant   0.2
# 2  Vegetarian / Vegan Restaurant   0.2
# 3                          Diner   0.2
# 4                           Café   0.2
#
#
# ----International Airport ----
#                  venue  freq
# 0              Airport  0.67
# 1       Duty-free Shop  0.33
# 2          Music Venue  0.00
# 3  Monument / Landmark  0.00
# 4                Motel  0.00
#
#
# ----Irla ----
#                 venue  freq
# 0      Ice Cream Shop  0.25
# 1  Seafood Restaurant  0.25
# 2  Miscellaneous Shop  0.12
# 3        Burger Joint  0.12
# 4   Electronics Store  0.12
#
#
# ----J B Nagar ----
#                venue  freq
# 0  Indian Restaurant  0.15
# 1               Café  0.15
# 2         Restaurant  0.15
# 3        Pizza Place  0.10
# 4              Hotel  0.10
#
#
# ----J J Hospital ----
#                venue  freq
# 0       Dessert Shop  0.25
# 1  Indian Restaurant  0.12
# 2         Restaurant  0.12
# 3     Ice Cream Shop  0.12
# 4     Breakfast Spot  0.12
#
#
# ----Jacob Circle ----
#                venue  freq
# 0             Bakery   0.2
# 1      Women's Store   0.2
# 2  Indian Restaurant   0.2
# 3      Jewelry Store   0.2
# 4         Restaurant   0.2
#
#
# ----Juhu ----
#                            venue  freq
# 0                    Pizza Place  0.25
# 1              Indian Restaurant  0.25
# 2  Vegetarian / Vegan Restaurant  0.25
# 3                           Café  0.25
# 4                    Music Venue  0.00
#
#
# ----Kalachowki ----
#            venue  freq
# 0         Bakery  0.25
# 1     Whisky Bar  0.25
# 2  Train Station  0.25
# 3          Plaza  0.25
# 4        Airport  0.00
#
#
# ----Kalbadevi ----
#                venue  freq
# 0  Indian Restaurant  0.46
# 1      Jewelry Store  0.15
# 2               Food  0.08
# 3               Café  0.08
# 4                Bar  0.08
#
#
# ----Kamathipura ----
#                        venue  freq
# 0          Indian Restaurant   0.2
# 1       Fast Food Restaurant   0.2
# 2           Department Store   0.1
# 3                 Donut Shop   0.1
# 4  Middle Eastern Restaurant   0.1
#
#
# ----Kandivali Rs ----
#                       venue  freq
# 0        Chinese Restaurant  0.25
# 1                  Pharmacy  0.12
# 2                    Bakery  0.12
# 3              Dessert Shop  0.12
# 4  Bike Rental / Bike Share  0.12
#
#
# ----Kapad Bazar ----
#                   venue  freq
# 0     Indian Restaurant  0.18
# 1  Fast Food Restaurant  0.18
# 2                 Beach  0.06
# 3        Breakfast Spot  0.06
# 4             Hotel Bar  0.06
#
#
# ----Khar Colony ----
#                 venue  freq
# 0   Indian Restaurant  0.12
# 1              Lounge  0.09
# 2  Italian Restaurant  0.06
# 3         Coffee Shop  0.06
# 4    Asian Restaurant  0.06
#
#
# ----Khar Delivery ----
#                venue  freq
# 0  Indian Restaurant  0.18
# 1                Bar  0.11
# 2             Lounge  0.07
# 3                Pub  0.07
# 4                Gym  0.04
#
#
# ----Kherwadi ----
#                venue  freq
# 0  Indian Restaurant  0.25
# 1         Restaurant  0.17
# 2                Bar  0.17
# 3           Platform  0.08
# 4               Café  0.08
#
#
# ----Kidwai Nagar Mumbai ----
#                venue  freq
# 0  Convention Center   0.2
# 1      Movie Theater   0.2
# 2         Print Shop   0.2
# 3        Flower Shop   0.2
# 4       Cupcake Shop   0.2
#
#
# ----L B S N E Collage ----
#                 venue  freq
# 0   Indian Restaurant  0.16
# 1                Café  0.16
# 2              Lounge  0.10
# 3  Seafood Restaurant  0.06
# 4                 Pub  0.06
#
#
# ----Lal Baug ----
#                      venue  freq
# 0        Indian Restaurant   0.4
# 1                    Plaza   0.2
# 2         Asian Restaurant   0.2
# 3  North Indian Restaurant   0.2
# 4                  Airport   0.0
#
#
# ----M A Marg ----
#                  venue  freq
# 0    Indian Restaurant  0.67
# 1  Indie Movie Theater  0.11
# 2   Miscellaneous Shop  0.11
# 3                 Café  0.11
# 4              Airport  0.00
#
#
# ----M P T ----
#                      venue  freq
# 0          Harbor / Marina  0.50
# 1                    Hotel  0.25
# 2        Convenience Store  0.25
# 3      Indie Movie Theater  0.00
# 4  New American Restaurant  0.00
#
#
# ----Madh ----
#                   venue  freq
# 0                 Beach  0.50
# 1                 Motel  0.25
# 2  Arts & Entertainment  0.25
# 3               Airport  0.00
# 4           Music Venue  0.00
#
#
# ----Madhavbaug ----
#                  venue  freq
# 0    Indian Restaurant  0.50
# 1                Hotel  0.25
# 2          Pizza Place  0.25
# 3          Music Venue  0.00
# 4  Monument / Landmark  0.00
#
#
# ----Mahim ----
#                   venue  freq
# 0     Indian Restaurant  0.22
# 1  Fast Food Restaurant  0.11
# 2                  Café  0.07
# 3    Chinese Restaurant  0.07
# 4        Breakfast Spot  0.04
#
#
# ----Mahim Bazar ----
#                   venue  freq
# 0     Indian Restaurant  0.21
# 1  Fast Food Restaurant  0.16
# 2                 Beach  0.05
# 3           Pizza Place  0.05
# 4         Moving Target  0.05
#
#
# ----Mahim East ----
#          venue  freq
# 0    Juice Bar  0.25
# 1  Coffee Shop  0.25
# 2         Café  0.25
# 3       Bakery  0.25
# 4      Airport  0.00
#
#
# ----Malabar Hill ----
#           venue  freq
# 0          Park   0.4
# 1  Dessert Shop   0.2
# 2           Gym   0.2
# 3    Restaurant   0.2
# 4       Airport   0.0
#
#
# ----Mantralaya Mumbai ----
#                   venue  freq
# 0     Indian Restaurant  0.13
# 1                  Café  0.11
# 2  Fast Food Restaurant  0.08
# 3           Coffee Shop  0.05
# 4    Chinese Restaurant  0.03
#
#
# ----Marine Lines ----
#                 venue  freq
# 0   Indian Restaurant  0.19
# 1              Bakery  0.08
# 2                Café  0.08
# 3      Cricket Ground  0.08
# 4  Chinese Restaurant  0.04
#
#
# ----Marol Bazar ----
#                      venue  freq
# 0        Indian Restaurant  0.50
# 1     Gym / Fitness Center  0.25
# 2              Coffee Shop  0.25
# 3                  Airport  0.00
# 4  New American Restaurant  0.00
#
#
# ----Marol Naka ----
#                venue  freq
# 0               Café  0.15
# 1  Indian Restaurant  0.11
# 2          Nightclub  0.07
# 3         Restaurant  0.07
# 4              Hotel  0.07
#
#
# ----Matunga ----
#                venue  freq
# 0  Indian Restaurant  0.20
# 1               Café  0.07
# 2     Ice Cream Shop  0.07
# 3        Snack Place  0.07
# 4                Bar  0.05
#
#
# ----Mazgaon ----
#                venue  freq
# 0     Ice Cream Shop  0.25
# 1  Indian Restaurant  0.25
# 2       Dessert Shop  0.25
# 3               Café  0.25
# 4        Music Venue  0.00
#
#
# ----Mazgaon Dock ----
#                      venue  freq
# 0                   Bakery  0.50
# 1      Government Building  0.25
# 2        Convenience Store  0.25
# 3  New American Restaurant  0.00
# 4                    Motel  0.00
#
#
# ----Mazgaon Road ----
#          venue  freq
# 0    Hotel Bar   0.2
# 1       Garden   0.2
# 2  Art Gallery   0.2
# 3         Café   0.2
# 4          Gym   0.2
#
#
# ----Mori Road ----
#                venue  freq
# 0        Pizza Place  0.22
# 1     Ice Cream Shop  0.11
# 2  Recreation Center  0.11
# 3  Indian Restaurant  0.11
# 4   Sculpture Garden  0.11
#
#
# ----Mumbai Central ----
#                 venue  freq
# 0   Indian Restaurant  0.12
# 1         Pizza Place  0.12
# 2  Mughlai Restaurant  0.12
# 3        Dessert Shop  0.12
# 4               Diner  0.12
#
#
# ----Mumbai G P O ----
#                venue  freq
# 0  Indian Restaurant  0.16
# 1         Irani Cafe  0.11
# 2               Café  0.11
# 3                Bar  0.05
# 4             Hostel  0.05
#
#
# ----N S Patkar Marg ----
#                venue  freq
# 0  Indian Restaurant  0.20
# 1         Restaurant  0.10
# 2          Gastropub  0.05
# 3                Bar  0.05
# 4     Clothing Store  0.05
#
#
# ----Nagardas Road ----
#                venue  freq
# 0     Ice Cream Shop  0.14
# 1  Indian Restaurant  0.14
# 2     Sandwich Place  0.14
# 3        Bus Station  0.14
# 4          Juice Bar  0.14
#
#
# ----Naigaon Mumbai ----
#                venue  freq
# 0  Indian Restaurant  0.25
# 1              Diner  0.25
# 2          Pool Hall  0.25
# 3                Bar  0.25
# 4            Airport  0.00
#
#
# ----Nariman Point ----
#                       venue  freq
# 0         Indian Restaurant  0.08
# 1                   Theater  0.08
# 2        Italian Restaurant  0.08
# 3  Mediterranean Restaurant  0.05
# 4                Restaurant  0.05
#
#
# ----Nehru Nagar Mumbai ----
#                  venue  freq
# 0       Cricket Ground  0.17
# 1    Convenience Store  0.17
# 2           Playground  0.17
# 3                Diner  0.17
# 4  Arts & Crafts Store  0.17
#
#
# ----Netajinagar ----
#                      venue  freq
# 0              Pizza Place  0.33
# 1                      Bar  0.33
# 2           Clothing Store  0.33
# 3  New American Restaurant  0.00
# 4                    Motel  0.00
#
#
# ----New Prabhadevi Road ----
#                  venue  freq
# 0               Bakery  0.18
# 1  American Restaurant  0.09
# 2          Bus Station  0.09
# 3  Japanese Restaurant  0.09
# 4    Indian Restaurant  0.09
#
#
# ----New Yogakshema ----
#                   venue  freq
# 0                 Hotel  0.10
# 1            Restaurant  0.08
# 2    Italian Restaurant  0.08
# 3  Fast Food Restaurant  0.08
# 4     Indian Restaurant  0.06
#
#
# ----Nitie ----
#                 venue  freq
# 0          Restaurant  0.29
# 1               Hotel  0.14
# 2   Indian Restaurant  0.14
# 3  Italian Restaurant  0.14
# 4         Coffee Shop  0.14
#
#
# ----Opera House ----
#                   venue  freq
# 0     Indian Restaurant  0.10
# 1  Fast Food Restaurant  0.10
# 2        Ice Cream Shop  0.08
# 3           Coffee Shop  0.06
# 4             Juice Bar  0.06
#
#
# ----Parel ----
#                  venue  freq
# 0    Indian Restaurant  0.31
# 1          Coffee Shop  0.15
# 2          Snack Place  0.08
# 3            Cafeteria  0.08
# 4  Sporting Goods Shop  0.08
#
#
# ----Parel Naka ----
#                              venue  freq
# 0                              Spa   1.0
# 1                          Airport   0.0
# 2                      Music Store   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4              Monument / Landmark   0.0
#
#
# ----Prabhadevi ----
#                 venue  freq
# 0   Indian Restaurant  0.14
# 1                Café  0.14
# 2              Bakery  0.09
# 3  Chinese Restaurant  0.09
# 4   Mobile Phone Shop  0.05
#
#
# ----Princess Dock ----
#                              venue  freq
# 0                            Hotel   1.0
# 1                        Pet Store   0.0
# 2  Molecular Gastronomy Restaurant   0.0
# 3              Monument / Landmark   0.0
# 4                            Motel   0.0
#
#
# ----Rajbhavan Mumbai ----
#                      venue  freq
# 0       Chinese Restaurant   1.0
# 1                  Airport   0.0
# 2  New American Restaurant   0.0
# 3                    Motel   0.0
# 4            Movie Theater   0.0
#
#
# ----Ramwadi ----
#                   venue  freq
# 0     Indian Restaurant  0.38
# 1         Jewelry Store  0.25
# 2                  Food  0.12
# 3           Bus Station  0.12
# 4  Fast Food Restaurant  0.12
#
#
# ----Ranade Road ----
#                   venue  freq
# 0     Indian Restaurant  0.19
# 1         Movie Theater  0.10
# 2        Breakfast Spot  0.06
# 3  Fast Food Restaurant  0.06
# 4           Flower Shop  0.06
#
#
# ----Reay Road ----
#                  venue  freq
# 0  Government Building   0.5
# 1                  Bar   0.5
# 2              Airport   0.0
# 3  Monument / Landmark   0.0
# 4                Motel   0.0
#
#
# ----S C Court ----
#                   venue  freq
# 0     Indian Restaurant  0.19
# 1  Fast Food Restaurant  0.09
# 2                  Café  0.07
# 3           Coffee Shop  0.05
# 4                Bakery  0.04
#
#
# ----S V Marg ----
#                   venue  freq
# 0     Indian Restaurant  0.20
# 1    Chinese Restaurant  0.13
# 2           Snack Place  0.07
# 3        Ice Cream Shop  0.07
# 4  Fast Food Restaurant  0.07
#
#
# ----S V S Marg ----
#                 venue  freq
# 0   Indian Restaurant  0.19
# 1      Ice Cream Shop  0.12
# 2  Chinese Restaurant  0.12
# 3     Thai Restaurant  0.06
# 4   Electronics Store  0.06
#
#
# ----Sahar P T Colony ----
#                venue  freq
# 0  Indian Restaurant  0.38
# 1              Hotel  0.12
# 2   Asian Restaurant  0.12
# 3        Coffee Shop  0.12
# 4                Bar  0.12
#
#
# ----Sahargaon ----
#                              venue  freq
# 0                              Spa   1.0
# 1                          Airport   0.0
# 2                      Music Store   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4              Monument / Landmark   0.0
#
#
# ----Santacruz Central ----
#             venue  freq
# 0   Jewelry Store  0.17
# 1  Ice Cream Shop  0.08
# 2        Boutique  0.08
# 3       Multiplex  0.08
# 4     Men's Store  0.08
#
#
# ----Santacruz East ----
#                  venue  freq
# 0   Chinese Restaurant  0.25
# 1   Seafood Restaurant  0.25
# 2                  Bar  0.25
# 3               Bakery  0.25
# 4  Monument / Landmark  0.00
#
#
# ----Santacruz P T Colony ----
#                 venue  freq
# 0             Airport  0.14
# 1  Seafood Restaurant  0.14
# 2                 Gym  0.14
# 3   Electronics Store  0.14
# 4          Playground  0.14
#
#
# ----Santacruz West ----
#             venue  freq
# 0   Jewelry Store  0.17
# 1  Ice Cream Shop  0.08
# 2        Boutique  0.08
# 3       Multiplex  0.08
# 4     Men's Store  0.08
#
#
# ----Secretariate ----
#                 venue  freq
# 0                Café  0.15
# 1                 Bar  0.08
# 2   Indian Restaurant  0.08
# 3      Breakfast Spot  0.05
# 4  Mughlai Restaurant  0.05
#
#
# ----Seepz ----
#                venue  freq
# 0  Indian Restaurant   0.2
# 1         Restaurant   0.2
# 2        Pizza Place   0.1
# 3        Bus Station   0.1
# 4               Lake   0.1
#
#
# ----Sewri ----
#              venue  freq
# 0      Bus Station  0.25
# 1    Train Station  0.25
# 2  Harbor / Marina  0.25
# 3      Flea Market  0.25
# 4          Airport  0.00
#
#
# ----Shivaji Park Mumbai ----
#                 venue  freq
# 0   Indian Restaurant  0.17
# 1  Chinese Restaurant  0.12
# 2                 Bar  0.07
# 3      Ice Cream Shop  0.07
# 4         Coffee Shop  0.07
#
#
# ----Sion ----
#                            venue  freq
# 0              Indian Restaurant  0.14
# 1           Gym / Fitness Center  0.10
# 2  Vegetarian / Vegan Restaurant  0.10
# 3                         Bakery  0.05
# 4                  Grocery Store  0.05
#
#
# ----Stock Exchange ----
#                 venue  freq
# 0   Indian Restaurant  0.22
# 1                Café  0.10
# 2  Seafood Restaurant  0.07
# 3  Chinese Restaurant  0.05
# 4         Coffee Shop  0.05
#
#
# ----Tajmahal ----
#                venue  freq
# 0               Café  0.12
# 1              Hotel  0.08
# 2                Bar  0.08
# 3        Coffee Shop  0.08
# 4  Indian Restaurant  0.06
#
#
# ----Tardeo ----
#                            venue  freq
# 0              Indian Restaurant  0.11
# 1             Chinese Restaurant  0.11
# 2                    Pizza Place  0.11
# 3                 Ice Cream Shop  0.11
# 4  Vegetarian / Vegan Restaurant  0.11
#
#
# ----Thakurdwar ----
#            venue  freq
# 0     Food Truck  0.14
# 1       Aquarium  0.14
# 2      Gastropub  0.14
# 3  Train Station  0.14
# 4      Juice Bar  0.14
#
#
# ----Town Hall Mumbai ----
#                venue  freq
# 0  Indian Restaurant   0.2
# 1       Burger Joint   0.1
# 2             Lounge   0.1
# 3         Food Court   0.1
# 4        Pizza Place   0.1
#
#
# ----Tulsiwadi ----
#                   venue  freq
# 0    Chinese Restaurant  0.15
# 1     Indian Restaurant  0.10
# 2  Fast Food Restaurant  0.10
# 3         Shopping Mall  0.10
# 4    Italian Restaurant  0.05
#
#
# ----V J B Udyan ----
#                            venue  freq
# 0                          Hotel  0.22
# 1              Indian Restaurant  0.22
# 2                      Hotel Bar  0.11
# 3                    Pizza Place  0.11
# 4  Vegetarian / Vegan Restaurant  0.11
#
#
# ----V K Bhavan ----
#                      venue  freq
# 0     Fast Food Restaurant  0.12
# 1        Indian Restaurant  0.12
# 2                     Café  0.07
# 3              Snack Place  0.07
# 4  South Indian Restaurant  0.05
#
#
# ----V P Road ----
#                   venue  freq
# 0     Indian Restaurant  0.13
# 1             Juice Bar  0.13
# 2  Fast Food Restaurant  0.13
# 3     Electronics Store  0.13
# 4        Sandwich Place  0.07
#
#
# ----V W T C ----
#                 venue  freq
# 0  Italian Restaurant  0.12
# 1   Indian Restaurant  0.12
# 2               Hotel  0.06
# 3                 Bar  0.06
# 4                 Gym  0.06
#
#
# ----Vakola ----
#                 venue  freq
# 0               Hotel  0.11
# 1              Bakery  0.11
# 2      Clothing Store  0.11
# 3      Ice Cream Shop  0.05
# 4  Italian Restaurant  0.05
#
#
# ----Vesava ----
#                venue  freq
# 0               Café  0.29
# 1  Indian Restaurant  0.14
# 2   Asian Restaurant  0.14
# 3        Coffee Shop  0.14
# 4           Tea Room  0.14
#
#
# ----Vidyanagari ----
#                   venue  freq
# 0     Indian Restaurant  0.10
# 1        Ice Cream Shop  0.10
# 2  Fast Food Restaurant  0.10
# 3           Bus Station  0.05
# 4            Restaurant  0.05
#
#
# ----Vileeparle East ----
#                venue  freq
# 0               Café  0.21
# 1              Hotel  0.18
# 2        Coffee Shop  0.15
# 3                Bar  0.06
# 4  Indian Restaurant  0.06
#
#
# ----Vileparle Railway Station ----
#                venue  freq
# 0  Indian Restaurant  0.26
# 1        Coffee Shop  0.09
# 2         Food Truck  0.09
# 3     Sandwich Place  0.09
# 4           Tea Room  0.09
#
#
# ----Vileparle West ----
#                 venue  freq
# 0            Tea Room  0.16
# 1   Indian Restaurant  0.11
# 2         Coffee Shop  0.11
# 3           BBQ Joint  0.05
# 4  Chinese Restaurant  0.05
#
#
# ----Wadala ----
#          venue  freq
# 0  Pizza Place  0.17
# 1          Gym  0.17
# 2  Flea Market  0.17
# 3         Café  0.17
# 4       Bakery  0.17
#
#
# ----Wadala Rs ----
#                      venue  freq
# 0              Pizza Place  0.25
# 1              Coffee Shop  0.25
# 2     Fast Food Restaurant  0.25
# 3                     Café  0.25
# 4  New American Restaurant  0.00
#
#
# ----Worli ----
#                venue  freq
# 0  Indian Restaurant   0.2
# 1      Train Station   0.2
# 2                Spa   0.2
# 3               Café   0.2
# 4        Coffee Shop   0.2
#
#
# ----Worli Colony ----
#                venue  freq
# 0  Indian Restaurant   0.2
# 1      Train Station   0.2
# 2                Spa   0.2
# 3               Café   0.2
# 4        Coffee Shop   0.2
#
#
# ----Worli Naka ----
#                   venue  freq
# 0     Indian Restaurant  0.15
# 1        Ice Cream Shop  0.15
# 2                Bakery  0.08
# 3  Fast Food Restaurant  0.08
# 4            Food Court  0.08
#
#
# ----Worli Police Camp ----
#                 venue  freq
# 0      Ice Cream Shop  0.17
# 1   Indian Restaurant  0.08
# 2        Gourmet Shop  0.08
# 3  Chinese Restaurant  0.08
# 4                Food  0.08
#
#
# ----Worli Sea Face ----
#             venue  freq
# 0  Scenic Lookout   0.4
# 1      Smoke Shop   0.2
# 2          Arcade   0.2
# 3     Art Gallery   0.2
# 4     Music Store   0.0

# %%
#put into a pandas dataframe
#write a function to sort the venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]
#create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 8
indicators = ['st', 'nd', 'rd']
# create columns according to number of top venues
columns = ['Area']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
# create a new dataframe
areas_venues_sorted = pd.DataFrame(columns=columns)
areas_venues_sorted['Area'] = bintang_grouped['Area']
for ind in np.arange(bintang_grouped.shape[0]):
    areas_venues_sorted.iloc[ind, 1:] = return_most_common_venues(bintang_grouped.iloc[ind, :], num_top_venues)
areas_venues_sorted.head()
# Out:
#                 Area 1st Most Common Venue 2nd Most Common Venue  \
# 0  A I Staff Colony      Indian Restaurant                   Pub
# 1          Agripada                 Bakery     Indian Restaurant
# 2    Airport Mumbai                Airport        Duty-free Shop
# 3   Ambewadi Mumbai              Juice Bar  Fast Food Restaurant
# 4           Andheri                  Hotel     Indian Restaurant
#
#   3rd Most Common Venue          4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant                    Bus Station            Restaurant
# 1                   Gym                    Coffee Shop            Restaurant
# 2           Event Space                           Food           Flower Shop
# 3        Breakfast Spot  Vegetarian / Vegan Restaurant  Gym / Fitness Center
# 4    Seafood Restaurant  Vegetarian / Vegan Restaurant             Hotel Bar
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue
# 0             Multiplex           Yoga Studio           Fish Market
# 1           Yoga Studio           Event Space           Flea Market
# 2           Flea Market           Fish Market                 Field
# 3           Bus Station           Snack Place           Coffee Shop
# 4           Pizza Place      Department Store           Yoga Studio

# %% [markdown]
# <a id='kmeankl'></a>
# # K-mean Cluster Mumbai
# <div style="text-align: right">[Top](#toc)</div>

# %%
from sklearn.cluster import KMeans
# set number of clusters
kclusters = 5
bintang_grouped_clustering = bintang_grouped.drop('Area', 1)
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(bintang_grouped_clustering)
# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 
#create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
bintang_merged = bbintang
# add clustering labels
kmeans.labels_=np.append(kmeans.labels_, [1,0,1])
bintang_merged['Cluster Labels'] = kmeans.labels_
# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
bintang_merged = bintang_merged.join(areas_venues_sorted.set_index('Area'), on='Area')
bintang_merged.head()
# Out:
#    Postcode District               Area  Taluka PostalStatus   Latitude  \
# 0    400001   Mumbai         Bazargate   Mumbai   Sub Office  18.936518
# 1    400001   Mumbai             M P T   Mumbai   Sub Office  18.948288
# 2    400001   Mumbai    Stock Exchange   Mumbai   Sub Office  18.930012
# 3    400001   Mumbai          Tajmahal   Mumbai   Sub Office  18.921729
# 4    400001   Mumbai  Town Hall Mumbai   Mumbai   Sub Office  19.115063
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0  72.835823               1     Indian Restaurant                  Café
# 1  72.844163               1       Harbor / Marina                 Hotel
# 2  72.833639               1     Indian Restaurant                  Café
# 3  72.833031               1                  Café                   Bar
# 4  72.850029               1     Indian Restaurant                 Hotel
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0    Seafood Restaurant    Chinese Restaurant            Irani Cafe
# 1     Convenience Store          Cupcake Shop        Cricket Ground
# 2    Seafood Restaurant             Bookstore          Dessert Shop
# 3                 Hotel           Coffee Shop     Indian Restaurant
# 4            Food Court          Burger Joint           Pizza Place
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue
# 0                Hostel                Bakery                  Park
# 1                  Food           Flower Shop           Flea Market
# 2    Chinese Restaurant           Coffee Shop        Clothing Store
# 3          Cocktail Bar                   Pub    Mughlai Restaurant
# 4              Platform                  Café    Chinese Restaurant

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
mum_lat=19.228825
mum_lng=72.854118
#Finally, let's visualize the resulting clusters
# create map 3.1343385, 101.6863371
bb_clusters = folium.Map(location=[mum_lat, mum_lng], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(bintang_merged['Latitude'], bintang_merged['Longitude'], bintang_merged['Area'], bintang_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(bb_clusters)
       
bb_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id='analyzeJB'></a>
# # Analyze Pune
# <div style="text-align: right">[Top](#toc)</div>

# %%
# one hot encoding
jdt_onehot = pd.get_dummies(jdt_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
jdt_onehot['Area'] = jdt_venues['Area'] 

# move neighborhood column to the first column
fixed_columns = [jdt_onehot.columns[-1]] + list(jdt_onehot.columns[:-1])
jdt_onehot = jdt_onehot[fixed_columns]

#examine the new dataframe size after one hot encoding
print('{} rows were returned after one hot encoding.'.format(jdt_onehot.shape[0]))

#group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
jdt_grouped = jdt_onehot.groupby('Area').mean().reset_index()

#examine the new dataframe size after one hot encoding
print('{} rows were returned after grouping.'.format(jdt_grouped.shape[0]))
# Out:
# 911 rows were returned after one hot encoding.
# 110 rows were returned after grouping.

# %%
#print each neighborhood along with the top 5 most common venues
num_top_venues = 5

for hood in jdt_grouped['Area']:
    print("----"+hood+"----")
    temp = jdt_grouped[jdt_grouped['Area'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----9 Drd ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----A R Shala ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Afmc ----
#            venue  freq
# 0   Cupcake Shop  0.33
# 1      Racetrack  0.33
# 2  Track Stadium  0.33
# 3           Park  0.00
# 4      Multiplex  0.00
#
#
# ----Airport Pune ----
#                 venue  freq
# 0     Airport Service  0.22
# 1          Food Truck  0.11
# 2  Airport Food Court  0.11
# 3   Indian Restaurant  0.11
# 4           Juice Bar  0.11
#
#
# ----Akurdi ----
#                   venue  freq
# 0     Indian Restaurant   0.2
# 1           Snack Place   0.2
# 2            Restaurant   0.2
# 3  Fast Food Restaurant   0.2
# 4     Convenience Store   0.2
#
#
# ----Anandnagar Pune ----
#                   venue  freq
# 0     Indian Restaurant  0.33
# 1           Pizza Place  0.17
# 2           Snack Place  0.17
# 3                Bakery  0.17
# 4  Fast Food Restaurant  0.17
#
#
# ----Armament ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Aundh T S ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Bajirao Road ----
#                            venue  freq
# 0              Indian Restaurant  0.12
# 1                   Dessert Shop  0.12
# 2                 Ice Cream Shop  0.08
# 3  Vegetarian / Vegan Restaurant  0.08
# 4                  Jewelry Store  0.08
#
#
# ----Baner Pashan Link Road ----
#                   venue  freq
# 0  Fast Food Restaurant  0.18
# 1                Bakery  0.09
# 2                Bistro  0.09
# 3            Restaurant  0.09
# 4                  Café  0.09
#
#
# ----Baner Road ----
#                      venue  freq
# 0        Indian Restaurant  0.35
# 1                  Brewery  0.06
# 2                   Lounge  0.06
# 3  New American Restaurant  0.06
# 4              Pizza Place  0.06
#
#
# ----Bhavani Peth ----
#                venue  freq
# 0        Snack Place   1.0
# 1  Accessories Store   0.0
# 2                Pub   0.0
# 3              Plaza   0.0
# 4         Playground   0.0
#
#
# ----Bhosari I E ----
#                venue  freq
# 0  Indian Restaurant  0.23
# 1                Bar  0.15
# 2           Tea Room  0.08
# 3      Train Station  0.08
# 4  Electronics Store  0.08
#
#
# ----Bhosarigoan ----
#                   venue  freq
# 0              Tea Room   0.2
# 1  Karnataka Restaurant   0.2
# 2  Gym / Fitness Center   0.2
# 3           Flea Market   0.2
# 4           Chaat Place   0.2
#
#
# ----Bhusari Colony ----
#                venue  freq
# 0  Indian Restaurant  0.50
# 1               Café  0.25
# 2    Motorcycle Shop  0.12
# 3       Liquor Store  0.12
# 4   Parsi Restaurant  0.00
#
#
# ----Bibvewadi ----
#             venue  freq
# 0  Breakfast Spot   0.2
# 1          Bakery   0.2
# 2     Pizza Place   0.2
# 3     Snack Place   0.2
# 4    Dessert Shop   0.2
#
#
# ----Botanical Garden Pune ----
#                      venue  freq
# 0                   Garden  0.33
# 1                      Gym  0.33
# 2         Business Service  0.33
# 3        Accessories Store  0.00
# 4  North Indian Restaurant  0.00
#
#
# ----C D A O ----
#                venue  freq
# 0  Indian Restaurant  0.33
# 1        Coffee Shop  0.33
# 2          BBQ Joint  0.33
# 3          Pool Hall  0.00
# 4              Plaza  0.00
#
#
# ----C M E ----
#                 venue  freq
# 0   Indian Restaurant  0.10
# 1  Chinese Restaurant  0.08
# 2  Italian Restaurant  0.08
# 3          Donut Shop  0.08
# 4         Coffee Shop  0.08
#
#
# ----Chinchwad East ----
#                venue  freq
# 0  Indian Restaurant  0.19
# 1      Shopping Mall  0.10
# 2        Pizza Place  0.10
# 3     Clothing Store  0.10
# 4          Multiplex  0.05
#
#
# ----Chinchwadgaon ----
#                venue  freq
# 0  Indian Restaurant  0.19
# 1      Shopping Mall  0.10
# 2        Pizza Place  0.10
# 3     Clothing Store  0.10
# 4          Multiplex  0.05
#
#
# ----Congress House Road ----
#                venue  freq
# 0  Indian Restaurant  0.33
# 1                Bar  0.13
# 2    Motorcycle Shop  0.07
# 3            Theater  0.07
# 4               Café  0.07
#
#
# ----Dapodi ----
#                venue  freq
# 0       Dessert Shop  0.25
# 1      Train Station  0.25
# 2              Hotel  0.25
# 3          Cafeteria  0.25
# 4  Accessories Store  0.00
#
#
# ----Dapodi Bazar ----
#                   venue  freq
# 0      Department Store   0.2
# 1          Dessert Shop   0.2
# 2           Coffee Shop   0.2
# 3           Snack Place   0.2
# 4  Fast Food Restaurant   0.2
#
#
# ----Deccan Gymkhana ----
#                            venue  freq
# 0              Indian Restaurant  0.21
# 1  Vegetarian / Vegan Restaurant  0.06
# 2           Fast Food Restaurant  0.06
# 3                           Café  0.04
# 4                    Coffee Shop  0.04
#
#
# ----Dhankawadi ----
#                venue  freq
# 0  Indian Restaurant  0.33
# 1        Snack Place  0.33
# 2         Restaurant  0.33
# 3  Accessories Store  0.00
# 4               Park  0.00
#
#
# ----Dhanori ----
#                             venue  freq
# 0                     Bus Station   1.0
# 1               Accessories Store   0.0
# 2  Multicuisine Indian Restaurant   0.0
# 3                       Pool Hall   0.0
# 4                           Plaza   0.0
#
#
# ----Dr B A Chowk ----
#                      venue  freq
# 0       Seafood Restaurant  0.29
# 1              Snack Place  0.14
# 2  Comfort Food Restaurant  0.14
# 3          Bed & Breakfast  0.14
# 4           Sandwich Place  0.14
#
#
# ----East Khadki ----
#                             venue  freq
# 0                Department Store   0.5
# 1            Medical Supply Store   0.5
# 2               Accessories Store   0.0
# 3  Multicuisine Indian Restaurant   0.0
# 4                           Plaza   0.0
#
#
# ----Ex Serviceman Colony ----
#                   venue  freq
# 0  Fast Food Restaurant  0.11
# 1           Coffee Shop  0.11
# 2                  Café  0.11
# 3     Accessories Store  0.06
# 4         Bowling Alley  0.06
#
#
# ----Film Institute ----
#                    venue  freq
# 0                   Café  0.21
# 1            Snack Place  0.16
# 2     Seafood Restaurant  0.11
# 3      Indian Restaurant  0.05
# 4  General Entertainment  0.05
#
#
# ----Ganeshkhind ----
#                  venue  freq
# 0  Sporting Goods Shop   0.2
# 1    Electronics Store   0.2
# 2          Bus Station   0.1
# 3  Arts & Crafts Store   0.1
# 4           Restaurant   0.1
#
#
# ----Ghorpade Peth ----
#                   venue  freq
# 0            Shoe Store   0.2
# 1                  Bank   0.2
# 2            Donut Shop   0.2
# 3      Asian Restaurant   0.2
# 4  Fast Food Restaurant   0.2
#
#
# ----Ghorpuri Bazar ----
#                venue  freq
# 0               Park   1.0
# 1  Accessories Store   0.0
# 2     Ice Cream Shop   0.0
# 3          Pool Hall   0.0
# 4              Plaza   0.0
#
#
# ----Govt Polytechnic ----
#                  venue  freq
# 0   Italian Restaurant  0.11
# 1           Food Court  0.11
# 2    Indian Restaurant  0.11
# 3  Dumpling Restaurant  0.11
# 4          Pizza Place  0.11
#
#
# ----Guruwar Peth ----
#             venue  freq
# 0        Pharmacy  0.33
# 1       Juice Bar  0.33
# 2  Ice Cream Shop  0.33
# 3           Plaza  0.00
# 4      Playground  0.00
#
#
# ----Hadapsar ----
#                   venue  freq
# 0  Fast Food Restaurant  0.23
# 1     Indian Restaurant  0.23
# 2                 Plaza  0.08
# 3           Coffee Shop  0.08
# 4    Chinese Restaurant  0.08
#
#
# ----Hadpsar I E ----
#                venue  freq
# 0  Indian Restaurant  0.23
# 1                Bar  0.15
# 2           Tea Room  0.08
# 3      Train Station  0.08
# 4  Electronics Store  0.08
#
#
# ----Indrayaninagar ----
#                venue  freq
# 0  Indian Restaurant  0.25
# 1        Pizza Place  0.25
# 2                Gym  0.25
# 3  Convenience Store  0.25
# 4         Playground  0.00
#
#
# ----Kapad Ganj ----
#                      venue  freq
# 0        Indian Restaurant   0.2
# 1              Flea Market   0.2
# 2             Neighborhood   0.2
# 3      Arts & Crafts Store   0.2
# 4  Fruit & Vegetable Store   0.2
#
#
# ----Karvenagar ----
#                      venue  freq
# 0                   Bakery   0.4
# 1           Breakfast Spot   0.2
# 2               Food Truck   0.2
# 3              Snack Place   0.2
# 4  North Indian Restaurant   0.0
#
#
# ----Kasarwadi ----
#                   venue  freq
# 0     Indian Restaurant  0.25
# 1              Platform  0.25
# 2  Fast Food Restaurant  0.25
# 3           Bus Station  0.25
# 4             Multiplex  0.00
#
#
# ----Kasba Peth ----
#                 venue  freq
# 0   Indian Restaurant  0.33
# 1  Italian Restaurant  0.33
# 2         Coffee Shop  0.33
# 3   Accessories Store  0.00
# 4            Pharmacy  0.00
#
#
# ----Katraj ----
#                             venue  freq
# 0               Indian Restaurant  0.67
# 1                     Snack Place  0.33
# 2               Accessories Store  0.00
# 3  Multicuisine Indian Restaurant  0.00
# 4                           Plaza  0.00
#
#
# ----Khadakwasla R S ----
#                             venue  freq
# 0               Indian Restaurant   0.5
# 1                     Snack Place   0.5
# 2               Accessories Store   0.0
# 3  Multicuisine Indian Restaurant   0.0
# 4                           Plaza   0.0
#
#
# ----Khadki ----
#                             venue  freq
# 0                Department Store   0.5
# 1            Medical Supply Store   0.5
# 2               Accessories Store   0.0
# 3  Multicuisine Indian Restaurant   0.0
# 4                           Plaza   0.0
#
#
# ----Khadki Bazar ----
#                      venue  freq
# 0         Department Store  0.50
# 1     Medical Supply Store  0.25
# 2                   Bakery  0.25
# 3        Accessories Store  0.00
# 4  New American Restaurant  0.00
#
#
# ----Khondhwa Kh ----
#                            venue  freq
# 0      Middle Eastern Restaurant   0.1
# 1                 Ice Cream Shop   0.1
# 2  Vegetarian / Vegan Restaurant   0.1
# 3                           Café   0.1
# 4                     Restaurant   0.1
#
#
# ----Kondhwa Bk ----
#                            venue  freq
# 0      Middle Eastern Restaurant   0.1
# 1                 Ice Cream Shop   0.1
# 2  Vegetarian / Vegan Restaurant   0.1
# 3                           Café   0.1
# 4                     Restaurant   0.1
#
#
# ----Kondhwa Lh ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Kothrud ----
#                venue  freq
# 0     Breakfast Spot  0.27
# 1  Indian Restaurant  0.18
# 2     Sandwich Place  0.18
# 3     Ice Cream Shop  0.09
# 4         Food Court  0.09
#
#
# ----Kunal Icon Pimple Saudagar ----
#                   venue  freq
# 0        Ice Cream Shop  0.14
# 1           Pizza Place  0.14
# 2                  Café  0.14
# 3        Sandwich Place  0.14
# 4  Fast Food Restaurant  0.14
#
#
# ----Lohogaon ----
#                venue  freq
# 0              Hotel   1.0
# 1  Accessories Store   0.0
# 2    Motorcycle Shop   0.0
# 3              Plaza   0.0
# 4         Playground   0.0
#
#
# ----Lokmanyanagar ----
#                venue  freq
# 0  Indian Restaurant  0.38
# 1     Breakfast Spot  0.08
# 2       Concert Hall  0.08
# 3        Coffee Shop  0.08
# 4         Playground  0.08
#
#
# ----M Phulenagar ----
#                             venue  freq
# 0               Indian Restaurant   1.0
# 1               Accessories Store   0.0
# 2  Multicuisine Indian Restaurant   0.0
# 3                       Pool Hall   0.0
# 4                           Plaza   0.0
#
#
# ----Mangalwar Peth Pune ----
#                 venue  freq
# 0          Donut Shop   0.2
# 1      Sandwich Place   0.2
# 2  Seafood Restaurant   0.2
# 3             Brewery   0.2
# 4              Bakery   0.2
#
#
# ----Market Yard Pune ----
#                venue  freq
# 0  Indian Restaurant  0.50
# 1  Mobile Phone Shop  0.25
# 2                Gym  0.25
# 3               Park  0.00
# 4          Multiplex  0.00
#
#
# ----Masulkar Colony ----
#                 venue  freq
# 0        Dessert Shop  0.33
# 1            Tea Room  0.17
# 2  Chinese Restaurant  0.17
# 3         Pizza Place  0.17
# 4                Park  0.17
#
#
# ----Model Colony ----
#                  venue  freq
# 0    Indian Restaurant  0.19
# 1         Dessert Shop  0.19
# 2   Italian Restaurant  0.06
# 3   Chinese Restaurant  0.06
# 4  Dumpling Restaurant  0.06
#
#
# ----Mohamadwadi ----
#                  venue  freq
# 0  Fried Chicken Joint   0.5
# 1    Indian Restaurant   0.5
# 2    Accessories Store   0.0
# 3                Plaza   0.0
# 4           Playground   0.0
#
#
# ----Mundhva ----
#                            venue  freq
# 0      Middle Eastern Restaurant   0.1
# 1                 Ice Cream Shop   0.1
# 2  Vegetarian / Vegan Restaurant   0.1
# 3                           Café   0.1
# 4                     Restaurant   0.1
#
#
# ----Mundhva Av ----
#                             venue  freq
# 0               Indian Restaurant   1.0
# 1               Accessories Store   0.0
# 2  Multicuisine Indian Restaurant   0.0
# 3                       Pool Hall   0.0
# 4                           Plaza   0.0
#
#
# ----N I A ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----N I B M ----
#                   venue  freq
# 0     Indian Restaurant   0.4
# 1     Mobile Phone Shop   0.2
# 2                 Hotel   0.2
# 3  Fast Food Restaurant   0.2
# 4                  Park   0.0
#
#
# ----N W College ----
#                 venue  freq
# 0   Indian Restaurant  0.25
# 1       Historic Site  0.25
# 2    Department Store  0.12
# 3  Miscellaneous Shop  0.12
# 4              Bakery  0.12
#
#
# ----Nana Peth ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Narayan Peth ----
#                venue  freq
# 0  Indian Restaurant  0.20
# 1     Ice Cream Shop  0.13
# 2      Women's Store  0.07
# 3             Bakery  0.07
# 4       Dessert Shop  0.07
#
#
# ----Navsahyadri ----
#                venue  freq
# 0        Snack Place  0.18
# 1               Café  0.12
# 2          Juice Bar  0.12
# 3  Indian Restaurant  0.12
# 4    Badminton Court  0.12
#
#
# ----Nehrunagar Pune ----
#                 venue  freq
# 0   Indian Restaurant  0.25
# 1          Restaurant  0.25
# 2  Chinese Restaurant  0.25
# 3        Hockey Field  0.25
# 4    Parsi Restaurant  0.00
#
#
# ----P C N T ----
#                venue  freq
# 0  Indian Restaurant  0.29
# 1        Snack Place  0.29
# 2             Bakery  0.14
# 3              Diner  0.14
# 4   Asian Restaurant  0.14
#
#
# ----Parvati ----
#                              venue  freq
# 0  Southern / Soul Food Restaurant  0.17
# 1                              Gym  0.08
# 2                           Bakery  0.08
# 3                             Café  0.08
# 4                   Breakfast Spot  0.08
#
#
# ----Parvati Gaon ----
#                venue  freq
# 0  Indian Restaurant  0.33
# 1          Bookstore  0.33
# 2              Trail  0.33
# 3  Accessories Store  0.00
# 4               Park  0.00
#
#
# ----Pimple Saudagar ----
#                   venue  freq
# 0        Ice Cream Shop  0.29
# 1    Salon / Barbershop  0.14
# 2        Sandwich Place  0.14
# 3      Department Store  0.14
# 4  Fast Food Restaurant  0.14
#
#
# ----Pimpri Colony ----
#                venue  freq
# 0       Tennis Court  0.33
# 1     Ice Cream Shop  0.33
# 2               Café  0.33
# 3  Accessories Store  0.00
# 4       Neighborhood  0.00
#
#
# ----Pimpri P F ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Pimpri Waghire ----
#                venue  freq
# 0       Tennis Court  0.33
# 1     Ice Cream Shop  0.33
# 2               Café  0.33
# 3  Accessories Store  0.00
# 4       Neighborhood  0.00
#
#
# ----Punawale ----
#                venue  freq
# 0  Mobile Phone Shop   0.5
# 1   Asian Restaurant   0.5
# 2   Parsi Restaurant   0.0
# 3          Multiplex   0.0
# 4       Neighborhood   0.0
#
#
# ----Pune New Bazar ----
#                             venue  freq
# 0                     Bus Station   1.0
# 1               Accessories Store   0.0
# 2  Multicuisine Indian Restaurant   0.0
# 3                       Pool Hall   0.0
# 4                           Plaza   0.0
#
#
# ----Range Hills ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Rashtra Bhasha Bhavan ----
#                venue  freq
# 0  Indian Restaurant  0.20
# 1     Ice Cream Shop  0.13
# 2      Women's Store  0.07
# 3             Bakery  0.07
# 4       Dessert Shop  0.07
#
#
# ----Rasta Peth ----
#                      venue  freq
# 0        Convenience Store  0.12
# 1  Comfort Food Restaurant  0.12
# 2              Snack Place  0.12
# 3                     Café  0.12
# 4          Bed & Breakfast  0.12
#
#
# ----Raviwar Peth ----
#                venue  freq
# 0  Indian Restaurant  0.14
# 1         Restaurant  0.14
# 2  Food & Drink Shop  0.14
# 3        Flea Market  0.14
# 4            Brewery  0.14
#
#
# ----Roseland Residency Pimple Saudagar ----
#                   venue  freq
# 0        Ice Cream Shop  0.22
# 1           Pizza Place  0.11
# 2                  Café  0.11
# 3  Fast Food Restaurant  0.11
# 4    Salon / Barbershop  0.11
#
#
# ----Rupeenagar ----
#                             venue  freq
# 0               Mobile Phone Shop   1.0
# 1               Accessories Store   0.0
# 2  Multicuisine Indian Restaurant   0.0
# 3                       Pool Hall   0.0
# 4                           Plaza   0.0
#
#
# ----S P College ----
#                   venue  freq
# 0          Dessert Shop   0.1
# 1  Fast Food Restaurant   0.1
# 2     Indian Restaurant   0.1
# 3           Pizza Place   0.1
# 4        Ice Cream Shop   0.1
#
#
# ----S S C Exam Board ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Sachapir Street ----
#                   venue  freq
# 0     Indian Restaurant  0.30
# 1  Fast Food Restaurant  0.09
# 2           Snack Place  0.06
# 3    Chinese Restaurant  0.06
# 4        Breakfast Spot  0.06
#
#
# ----Sadashiv Peth ----
#                venue  freq
# 0  Indian Restaurant  0.31
# 1        Coffee Shop  0.12
# 2        Snack Place  0.12
# 3  Convenience Store  0.06
# 4     Breakfast Spot  0.06
#
#
# ----Salisbury Park ----
#                venue  freq
# 0     Breakfast Spot   0.5
# 1        Snack Place   0.5
# 2  Accessories Store   0.0
# 3              Plaza   0.0
# 4         Playground   0.0
#
#
# ----Sasanenagar ----
#                   venue  freq
# 0        Breakfast Spot   0.2
# 1                  Café   0.2
# 2           Pizza Place   0.2
# 3  Fast Food Restaurant   0.2
# 4      Department Store   0.2
#
#
# ----Shaniwar Peth Pune ----
#                 venue  freq
# 0   Indian Restaurant  0.27
# 1       Historic Site  0.18
# 2             Theater  0.09
# 3    Department Store  0.09
# 4  Seafood Restaurant  0.09
#
#
# ----Shivaji Housing Society ----
#          venue  freq
# 0       Lounge  0.10
# 1  Coffee Shop  0.10
# 2  IT Services  0.05
# 3       Bistro  0.05
# 4          Gym  0.05
#
#
# ----Shivajinagar Pune ----
#                   venue  freq
# 0     Indian Restaurant  0.33
# 1                 Hotel  0.17
# 2            Restaurant  0.17
# 3           Pizza Place  0.17
# 4  Fast Food Restaurant  0.17
#
#
# ----Shukrawar Peth Pune ----
#                            venue  freq
# 0  Vegetarian / Vegan Restaurant  0.27
# 1                   Dessert Shop  0.18
# 2                 History Museum  0.09
# 3              Mobile Phone Shop  0.09
# 4                       Tea Room  0.09
#
#
# ----Swargate ----
#               venue  freq
# 0        Shoe Store  0.25
# 1        Donut Shop  0.25
# 2  Asian Restaurant  0.25
# 3              Bank  0.25
# 4  Parsi Restaurant  0.00
#
#
# ----Swargate Chowk ----
#                             venue  freq
# 0                       Hotel Bar  0.25
# 1                  Clothing Store  0.25
# 2                             Gym  0.25
# 3  Multicuisine Indian Restaurant  0.25
# 4               Accessories Store  0.00
#
#
# ----T V Nagar ----
#              venue  freq
# 0   Ice Cream Shop  0.25
# 1        Bookstore  0.25
# 2              Gym  0.25
# 3         Tea Room  0.25
# 4  Motorcycle Shop  0.00
#
#
# ----Talwade ----
#                             venue  freq
# 0               Mobile Phone Shop   1.0
# 1               Accessories Store   0.0
# 2  Multicuisine Indian Restaurant   0.0
# 3                       Pool Hall   0.0
# 4                           Plaza   0.0
#
#
# ----Thathawade ----
#                            venue  freq
# 0              Indian Restaurant  0.50
# 1  Vegetarian / Vegan Restaurant  0.25
# 2                 Sandwich Place  0.25
# 3              Accessories Store  0.00
# 4               Parsi Restaurant  0.00
#
#
# ----Thergaon ----
#                            venue  freq
# 0              Accessories Store   0.2
# 1        North Indian Restaurant   0.2
# 2                Bed & Breakfast   0.2
# 3              Mobile Phone Shop   0.2
# 4  Vegetarian / Vegan Restaurant   0.2
#
#
# ----Vadgaon Budruk ----
#                venue  freq
# 0        Snack Place   1.0
# 1  Accessories Store   0.0
# 2                Pub   0.0
# 3              Plaza   0.0
# 4         Playground   0.0
#
#
# ----Vadgaon Sheri ----
#                             venue  freq
# 0           Rajasthani Restaurant   0.5
# 1                    Soccer Field   0.5
# 2               Accessories Store   0.0
# 3  Multicuisine Indian Restaurant   0.0
# 4                           Plaza   0.0
#
#
# ----Vidyanagar Pune ----
#                      venue  freq
# 0  South Indian Restaurant  0.33
# 1               Playground  0.33
# 2              Auto Garage  0.33
# 3        Accessories Store  0.00
# 4  North Indian Restaurant  0.00
#
#
# ----Vishrantwadi ----
#                      venue  freq
# 0        Indian Restaurant  0.25
# 1              Pizza Place  0.25
# 2                      Gym  0.12
# 3                     Café  0.12
# 4  South Indian Restaurant  0.12
#
#
# ----Wakad ----
#                venue  freq
# 0         Restaurant  0.25
# 1        Pizza Place  0.25
# 2                Gym  0.25
# 3               Café  0.25
# 4  Accessories Store  0.00
#
#
# ----Wanowarie ----
#                 venue  freq
# 0                Café  0.25
# 1         Coffee Shop  0.10
# 2      Breakfast Spot  0.10
# 3        Burger Joint  0.10
# 4  Falafel Restaurant  0.05
#
#
# ----Warje ----
#                   venue  freq
# 0     Indian Restaurant   0.4
# 1           Coffee Shop   0.2
# 2           Pizza Place   0.2
# 3  Fast Food Restaurant   0.2
# 4             Multiplex   0.0
#
#
# ----Yamunanagar ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00
#
#
# ----Yerwada ----
#                venue  freq
# 0         Donut Shop   1.0
# 1  Accessories Store   0.0
# 2                Pub   0.0
# 3              Plaza   0.0
# 4         Playground   0.0
#
#
# ----Yerwada T S ----
#                      venue  freq
# 0            Historic Site  0.50
# 1         Department Store  0.25
# 2                   Bakery  0.25
# 3             Neighborhood  0.00
# 4  New American Restaurant  0.00

# %%
#create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 8

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Area']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
areas_venues_sorted = pd.DataFrame(columns=columns)
areas_venues_sorted['Area'] = jdt_grouped['Area']

for ind in np.arange(jdt_grouped.shape[0]):
    areas_venues_sorted.iloc[ind, 1:] = return_most_common_venues(jdt_grouped.iloc[ind, :], num_top_venues)

areas_venues_sorted.head()
# Out:
#             Area 1st Most Common Venue 2nd Most Common Venue  \
# 0         9 Drd          Historic Site      Department Store
# 1     A R Shala          Historic Site      Department Store
# 2          Afmc              Racetrack          Cupcake Shop
# 3  Airport Pune        Airport Service             Juice Bar
# 4        Akurdi            Snack Place     Convenience Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                Bakery         Women's Store    Falafel Restaurant
# 1                Bakery         Women's Store    Falafel Restaurant
# 2         Track Stadium         Women's Store   Dumpling Restaurant
# 3     Indian Restaurant           Snack Place            Food Truck
# 4     Indian Restaurant  Fast Food Restaurant            Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue
# 0     Food & Drink Shop                  Food           Flea Market
# 1     Food & Drink Shop                  Food           Flea Market
# 2                  Food           Flea Market  Fast Food Restaurant
# 3  Fast Food Restaurant            Smoke Shop    Airport Food Court
# 4   Dumpling Restaurant                  Food           Flea Market

# %% [markdown]
# <a id='kmeanjb'></a>
# # K-mean Cluster Pune
# <div style="text-align: right">[Top](#toc)</div>

# %%
# set number of clusters
kclusters = 3

jdt_grouped_clustering = jdt_grouped.drop('Area', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(jdt_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

#create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
jdt_merged = jdt

kmeans.labels_=np.append(kmeans.labels_,kmeans.labels_[0:14])
# add clustering labels
jdt_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
jdt_merged = jdt_merged.join(areas_venues_sorted.set_index('Area'), on='Area')

jdt_merged.head() # check the last columns!
# Out:
#    Postcode District              Area     Taluka PostalStatus   Latitude  \
# 0    411001     Pune          C D A O   Pune City   Sub Office  18.515806
# 1    411001     Pune     Dr B A Chowk   Pune City   Sub Office  18.523306
# 2    411001     Pune   Ghorpuri Bazar   Pune City   Sub Office  18.525956
# 3    411001     Pune      N W College   Pune City   Sub Office  18.518135
# 4    411001     Pune  Pune Cantt East   Pune City   Sub Office  18.457955
#
#    Longitude  Cluster Labels 1st Most Common Venue    2nd Most Common Venue  \
# 0  73.927164               1           Coffee Shop        Indian Restaurant
# 1  73.869719               1    Seafood Restaurant  Comfort Food Restaurant
# 2  73.895290               2                  Park            Women's Store
# 3  73.855552               2     Indian Restaurant            Historic Site
# 4  73.791910               2                   NaN                      NaN
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0             BBQ Joint         Women's Store     Electronics Store
# 1       Bed & Breakfast        Sandwich Place                Bakery
# 2          Concert Hall          Cupcake Shop      Department Store
# 3    Miscellaneous Shop      Department Store        Ice Cream Shop
# 4                   NaN                   NaN                   NaN
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue
# 0     Food & Drink Shop                  Food           Flea Market
# 1           Snack Place    Falafel Restaurant                  Food
# 2          Dessert Shop                 Diner            Donut Shop
# 3                Bakery    Falafel Restaurant            Food Court
# 4                   NaN                   NaN                   NaN

# %%
#Finally, let's visualize the resulting clusters
# create map
jdt_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(jdt_merged['Latitude'], jdt_merged['Longitude'], jdt_merged['Area'], jdt_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(jdt_clusters)
       
jdt_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id='results'></a>
# # Results
# <div style="text-align: right">[Top](#toc)</div>

# %%
#Cluster 1 for Mumbai
bintang_merged.loc[bintang_merged['Cluster Labels'] == 0, bintang_merged.columns[[2] + list(range(5, bintang_merged.shape[1]))]]
# Out:
#                      Area   Latitude  Longitude  Cluster Labels  \
# 16                Asvini   18.900152  72.815235               0
# 17                Colaba   18.906703  72.814712               0
# 41          Jacob Circle   18.982146  72.830131               0
# 48          Dadar Colony   19.018913  72.852930               0
# 59            Worli Naka   18.999054  72.816961               0
# 68                  Sion   19.039021  72.861895               0
# 69    Nehru Nagar Mumbai   19.063990  72.882563               0
# 72         Cumballa Hill   20.593684  78.962880               0
# 79   Gokhale Road Mumbai   19.016786  72.835146               0
# 98             Reay Road   18.971022  72.845377               0
# 103         B P T Colony   19.012526  72.862625               0
# 109    Government Colony   19.060574  72.850440               0
# 144     Sahar P T Colony   19.100584  72.867843               0
#
#     1st Most Common Venue 2nd Most Common Venue  \
# 16    American Restaurant           Bus Station
# 17      Convenience Store                   Bar
# 41          Women's Store     Indian Restaurant
# 48          Deli / Bodega           Coffee Shop
# 59         Ice Cream Shop     Indian Restaurant
# 68      Indian Restaurant  Gym / Fitness Center
# 69      Convenience Store        Cricket Ground
# 72                    Spa           Yoga Studio
# 79      Convenience Store     Electronics Store
# 98                    Bar   Government Building
# 103         Women's Store            Food Court
# 109     Indian Restaurant                   Bar
# 144     Indian Restaurant                 Hotel
#
#              3rd Most Common Venue 4th Most Common Venue  \
# 16            Fast Food Restaurant           Yoga Studio
# 17                Asian Restaurant           Event Space
# 41                      Restaurant         Jewelry Store
# 48                          Garden                  Café
# 59              Seafood Restaurant      Asian Restaurant
# 68   Vegetarian / Vegan Restaurant                 Plaza
# 69                      Playground   Arts & Crafts Store
# 72               Electronics Store           Flower Shop
# 79               Indian Restaurant  Fast Food Restaurant
# 98                     Yoga Studio     Electronics Store
# 103                    Flower Shop           Flea Market
# 109                         Bistro                  Café
# 144                      Hotel Bar      Asian Restaurant
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 16            Event Space                  Food           Flower Shop
# 17                   Food           Flower Shop           Flea Market
# 41                 Bakery           Yoga Studio           Event Space
# 48            Yoga Studio           Event Space           Flower Shop
# 59   Fast Food Restaurant                  Café                   Bar
# 68                   Bank                Bakery                  Café
# 69                  Diner    Chinese Restaurant           Event Space
# 72            Flea Market           Fish Market                 Field
# 79            Coffee Shop    Chinese Restaurant    Seafood Restaurant
# 98            Flower Shop           Flea Market           Fish Market
# 103           Fish Market                 Field  Fast Food Restaurant
# 109            Restaurant             Multiplex           Pizza Place
# 144           Coffee Shop                   Bar           Yoga Studio
#
#     8th Most Common Venue
# 16            Flea Market
# 17            Fish Market
# 41            Flower Shop
# 48            Flea Market
# 59                 Bakery
# 68          Movie Theater
# 69            Flower Shop
# 72   Fast Food Restaurant
# 79            Flower Shop
# 98                  Field
# 103        Farmers Market
# 109    Chinese Restaurant
# 144           Event Space

# %%
#Cluster 2 for Mumbai
bintang_merged.loc[bintang_merged['Cluster Labels'] == 1, bintang_merged.columns[[2] + list(range(5, bintang_merged.shape[1]))]]
# Out:
#                            Area   Latitude  Longitude  Cluster Labels  \
# 0                    Bazargate   18.936518  72.835823               1
# 1                        M P T   18.948288  72.844163               1
# 2               Stock Exchange   18.930012  72.833639               1
# 3                     Tajmahal   18.921729  72.833031               1
# 4             Town Hall Mumbai   19.115063  72.850029               1
# 5                 Mumbai G P O   18.938956  72.837057               1
# 6                    Kalbadevi   18.948738  72.828883               1
# 7                      Ramwadi   18.950313  72.827458               1
# 8                    S C Court   18.931120  72.830150               1
# 9                   Thakurdwar   18.949847  72.822745               1
# 10             Ambewadi Mumbai   18.955627  72.821715               1
# 12                    Chaupati   18.954749  72.813882               1
# 13                     Girgaon   18.957229  72.819669               1
# 14                  Madhavbaug   19.112474  72.848127               1
# 15                 Opera House   18.956988  72.815216               1
# 18                Holiday Camp   19.093205  72.913813               1
# 19                     V W T C   18.914169  72.818242               1
# 20                Malabar Hill   18.954274  72.801325               1
# 21         Bharat Nagar Mumbai   19.064807  72.859485               1
# 22                  Grant Road   18.962999  72.817575               1
# 23             N S Patkar Marg   18.960020  72.808845               1
# 24                    S V Marg   19.021069  72.832912               1
# 25                      Tardeo   18.968150  72.812244               1
# 26               Falkland Road   18.960329  72.824279               1
# 27                J J Hospital   18.963068  72.833608               1
# 28                 Kamathipura   18.964892  72.826141               1
# 29                    M A Marg   19.032028  72.856286               1
# 32               Dockyard Road   18.967781  72.844465               1
# 33                Mazgaon Dock   18.967006  72.847926               1
# 34                Mazgaon Road   18.965609  72.838998               1
# ..                          ...        ...        ...             ...
# 115                    Andheri   19.113645  72.869734               1
# 116          Azad Nagar Mumbai   19.129245  72.836039               1
# 117          Santacruz Central   19.084338  72.835972               1
# 118             Santacruz West   19.084338  72.835972               1
# 119             Santacruz East   19.079370  72.856260               1
# 120                     Vakola   19.078878  72.850031               1
# 121                       Irla   19.108397  72.843424               1
# 122             Vileparle West   19.103052  72.846691               1
# 123               Hanuman Road   26.498359  78.604129               1
# 124            Vileeparle East   19.096378  72.856399               1
# 125  Vileparle Railway Station   19.099573  72.844133               1
# 126    Andheri Railway Station   19.119824  72.846531               1
# 127               H M P School   19.120370  72.845132               1
# 128                  J B Nagar   19.111062  72.865592               1
# 129                Marol Bazar   19.114069  72.878267               1
# 130                 Marol Naka   19.108117  72.879477               1
# 131                       Madh   19.164008  72.789509               1
# 132                     Vesava   18.988291  72.824457               1
# 133               Kandivali Rs   19.209942  72.837231               1
# 134               Andheri East   19.113645  72.869734               1
# 135              Nagardas Road   19.122286  72.850836               1
# 136                      Kurla   19.059984  72.889999               1
# 137                Netajinagar   19.072239  72.880532               1
# 138                      Nitie   19.139289  72.901494               1
# 139               Chakala Midc   19.119984  72.867964               1
# 140                      Seepz   19.126657  72.876655               1
# 141                Vidyanagari   19.074447  72.864102               1
# 142             Airport Mumbai   19.089560  72.865614               1
# 143      International Airport   19.089560  72.865614               1
# 145                  Sahargaon   20.593684  78.962880               1
#
#     1st Most Common Venue          2nd Most Common Venue  \
# 0       Indian Restaurant                           Café
# 1         Harbor / Marina                          Hotel
# 2       Indian Restaurant                           Café
# 3                    Café                            Bar
# 4       Indian Restaurant                          Hotel
# 5       Indian Restaurant                           Café
# 6       Indian Restaurant                  Jewelry Store
# 7       Indian Restaurant                  Jewelry Store
# 8       Indian Restaurant           Fast Food Restaurant
# 9              Food Truck                  Train Station
# 10              Juice Bar           Fast Food Restaurant
# 12      Indian Restaurant           Fast Food Restaurant
# 13              Juice Bar           Fast Food Restaurant
# 14      Indian Restaurant                          Hotel
# 15   Fast Food Restaurant              Indian Restaurant
# 18                   Café  Vegetarian / Vegan Restaurant
# 19      Indian Restaurant             Italian Restaurant
# 20                   Park                            Gym
# 21                   Park                   Dessert Shop
# 22      Electronics Store                     Food Truck
# 23      Indian Restaurant                     Restaurant
# 24      Indian Restaurant             Chinese Restaurant
# 25                 Bakery                    Pizza Place
# 26      Indian Restaurant                    Snack Place
# 27           Dessert Shop                         Bakery
# 28      Indian Restaurant           Fast Food Restaurant
# 29      Indian Restaurant             Miscellaneous Shop
# 32                 Bakery              Convenience Store
# 33                 Bakery              Convenience Store
# 34              Hotel Bar                    Art Gallery
# ..                    ...                            ...
# 115                 Hotel              Indian Restaurant
# 116                   Pub                            Bar
# 117         Jewelry Store                      Multiplex
# 118         Jewelry Store                      Multiplex
# 119                   Bar             Chinese Restaurant
# 120        Clothing Store                         Bakery
# 121        Ice Cream Shop             Seafood Restaurant
# 122              Tea Room                    Coffee Shop
# 123                   NaN                            NaN
# 124                  Café                          Hotel
# 125     Indian Restaurant                 Sandwich Place
# 126          Burger Joint              Indian Restaurant
# 127     Indian Restaurant                   Burger Joint
# 128            Restaurant              Indian Restaurant
# 129     Indian Restaurant           Gym / Fitness Center
# 130                  Café              Indian Restaurant
# 131                 Beach                          Motel
# 132                  Café                       Tea Room
# 133    Chinese Restaurant       Bike Rental / Bike Share
# 134                 Hotel              Indian Restaurant
# 135             Juice Bar                 Ice Cream Shop
# 136                   NaN                            NaN
# 137           Pizza Place                            Bar
# 138            Restaurant                         Lounge
# 139      Asian Restaurant             Seafood Restaurant
# 140            Restaurant              Indian Restaurant
# 141  Fast Food Restaurant                 Ice Cream Shop
# 142               Airport                 Duty-free Shop
# 143               Airport                 Duty-free Shop
# 145                   Spa                    Yoga Studio
#
#          3rd Most Common Venue          4th Most Common Venue  \
# 0           Seafood Restaurant             Chinese Restaurant
# 1            Convenience Store                   Cupcake Shop
# 2           Seafood Restaurant                      Bookstore
# 3                        Hotel                    Coffee Shop
# 4                   Food Court                   Burger Joint
# 5                   Irani Cafe                         Hostel
# 6                Movie Theater                            Bar
# 7                         Food                    Bus Station
# 8                         Café                    Coffee Shop
# 9                     Aquarium           Fast Food Restaurant
# 10              Breakfast Spot  Vegetarian / Vegan Restaurant
# 12              Ice Cream Shop                      Juice Bar
# 13           Electronics Store              Indian Restaurant
# 14                 Pizza Place                    Yoga Studio
# 15              Ice Cream Shop                    Coffee Shop
# 18           Indian Restaurant                          Diner
# 19             Thai Restaurant                            Bar
# 20                Dessert Shop                     Restaurant
# 21                      Lounge             Chinese Restaurant
# 22              Farmers Market                  Movie Theater
# 23              History Museum                    Pizza Place
# 24          Seafood Restaurant                    Snack Place
# 25                        Café             Chinese Restaurant
# 26        Fast Food Restaurant                    Yoga Studio
# 27              Breakfast Spot                 Ice Cream Shop
# 28   Middle Eastern Restaurant               Department Store
# 29         Indie Movie Theater                           Café
# 32           Indian Restaurant                            Gym
# 33         Government Building                    Yoga Studio
# 34                         Gym                         Garden
# ..                         ...                            ...
# 115         Seafood Restaurant  Vegetarian / Vegan Restaurant
# 116                Coffee Shop              Indian Restaurant
# 117                   Boutique                    Men's Store
# 118                   Boutique                    Men's Store
# 119                     Bakery             Seafood Restaurant
# 120                      Hotel              Indian Restaurant
# 121                  Multiplex                   Burger Joint
# 122          Indian Restaurant              Martial Arts Dojo
# 123                        NaN                            NaN
# 124                Coffee Shop              Indian Restaurant
# 125                 Food Truck                       Tea Room
# 126                 Food Court                           Café
# 127                 Restaurant           Fast Food Restaurant
# 128                       Café                          Hotel
# 129                Coffee Shop                    Yoga Studio
# 130                  Nightclub                          Hotel
# 131       Arts & Entertainment                    Yoga Studio
# 132          Indian Restaurant         Furniture / Home Store
# 133                   Pharmacy                            Gym
# 134         Seafood Restaurant  Vegetarian / Vegan Restaurant
# 135                Bus Station                         Lounge
# 136                        NaN                            NaN
# 137             Clothing Store                    Yoga Studio
# 138                      Hotel              Indian Restaurant
# 139          Indian Restaurant                          Diner
# 140                       Lake               Airport Terminal
# 141          Indian Restaurant                    Pizza Place
# 142                Event Space                           Food
# 143                Event Space                           Food
# 145          Electronics Store                    Flower Shop
#
#              5th Most Common Venue      6th Most Common Venue  \
# 0                       Irani Cafe                     Hostel
# 1                   Cricket Ground                       Food
# 2                     Dessert Shop         Chinese Restaurant
# 3                Indian Restaurant               Cocktail Bar
# 4                      Pizza Place                   Platform
# 5                              Bar                  Multiplex
# 6                             Café                       Food
# 7             Fast Food Restaurant                Event Space
# 8                           Bakery              Movie Theater
# 9                       Restaurant                  Gastropub
# 10            Gym / Fitness Center                Bus Station
# 12                            Café                Pizza Place
# 13                     Coffee Shop             Breakfast Spot
# 14                  Duty-free Shop                Flea Market
# 15                       Juice Bar          Electronics Store
# 18                          Lounge                Yoga Studio
# 19                             Spa                Coffee Shop
# 20               Electronics Store                Flea Market
# 21                  Sandwich Place                Coffee Shop
# 22              Chinese Restaurant  Middle Eastern Restaurant
# 23                       Bookstore       Fast Food Restaurant
# 24                    Dessert Shop                Coffee Shop
# 25   Vegetarian / Vegan Restaurant             Ice Cream Shop
# 26               Electronics Store                Flower Shop
# 27               Indian Restaurant                 Restaurant
# 28            Gym / Fitness Center           Asian Restaurant
# 29                     Event Space                       Food
# 32                            Café        Government Building
# 33                     Event Space                Flower Shop
# 34                            Café                Yoga Studio
# ..                             ...                        ...
# 115                      Hotel Bar                Pizza Place
# 116                    Pizza Place               Burger Joint
# 117                         Market                        Pub
# 118                         Market                        Pub
# 119                    Yoga Studio         Falafel Restaurant
# 120                Thai Restaurant         Chinese Restaurant
# 121              Electronics Store         Miscellaneous Shop
# 122                      Multiplex                 Food Truck
# 123                            NaN                        NaN
# 124                            Bar                Yoga Studio
# 125                    Coffee Shop                  Gift Shop
# 126                     Restaurant       Fast Food Restaurant
# 127                         Bakery                 Food Court
# 128                    Pizza Place         Seafood Restaurant
# 129                 Duty-free Shop                Flea Market
# 130                     Restaurant                Pizza Place
# 131                    Event Space                Flower Shop
# 132                    Coffee Shop           Asian Restaurant
# 133                   Dessert Shop       Fast Food Restaurant
# 134                      Hotel Bar                Pizza Place
# 135             Light Rail Station          Indian Restaurant
# 136                            NaN                        NaN
# 137              Electronics Store                Flea Market
# 138                    Coffee Shop         Italian Restaurant
# 139                     Restaurant                       Food
# 140  Vegetarian / Vegan Restaurant                Pizza Place
# 141                      Pet Store                Bus Station
# 142                    Flower Shop                Flea Market
# 143                    Flower Shop                Flea Market
# 145                    Flea Market                Fish Market
#
#     7th Most Common Venue          8th Most Common Venue
# 0                  Bakery                           Park
# 1             Flower Shop                    Flea Market
# 2             Coffee Shop                 Clothing Store
# 3                     Pub             Mughlai Restaurant
# 4                    Café             Chinese Restaurant
# 5             Coffee Shop             Chinese Restaurant
# 6             Cheese Shop                    Yoga Studio
# 7             Flower Shop                    Flea Market
# 8          Clothing Store             Chinese Restaurant
# 9               Juice Bar              Electronics Store
# 10            Snack Place                    Coffee Shop
# 12         Breakfast Spot                  Train Station
# 13            Snack Place                           Café
# 14            Fish Market                          Field
# 15     Italian Restaurant                    Pizza Place
# 18            Flea Market                    Fish Market
# 19             Food Truck                  Shopping Mall
# 20            Fish Market                          Field
# 21                  Diner                     Irani Cafe
# 22                 Lounge                       Platform
# 23                   Café                            Bar
# 24      Electronics Store                           Café
# 25      Indian Restaurant                    Snack Place
# 26            Flea Market                    Fish Market
# 27            Music Venue                    Yoga Studio
# 28             Donut Shop             Chinese Restaurant
# 29            Flower Shop                    Flea Market
# 32                 Garden              Electronics Store
# 33            Flea Market                    Fish Market
# 34            Event Space                    Flea Market
# ..                    ...                            ...
# 115      Department Store                    Yoga Studio
# 116         Bowling Alley                  Metro Station
# 117            Steakhouse            Japanese Restaurant
# 118            Steakhouse            Japanese Restaurant
# 119                  Food                    Flower Shop
# 120            Restaurant             Italian Restaurant
# 121          Dessert Shop                 Farmers Market
# 122                Market                    Snack Place
# 123                   NaN                            NaN
# 124            Food Court                    Men's Store
# 125                 Diner                         Lounge
# 126                Lounge                         Bakery
# 127           Yoga Studio             Falafel Restaurant
# 128  Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 129           Fish Market                          Field
# 130            Bagel Shop           Fast Food Restaurant
# 131           Flea Market                    Fish Market
# 132     Electronics Store                    Flea Market
# 133                Bakery                    Yoga Studio
# 134      Department Store                    Yoga Studio
# 135        Sandwich Place                   Dessert Shop
# 136                   NaN                            NaN
# 137           Fish Market                          Field
# 138           Yoga Studio                    Flea Market
# 139    Italian Restaurant             Chinese Restaurant
# 140           Bus Station                           Café
# 141    Chinese Restaurant                    Snack Place
# 142           Fish Market                          Field
# 143           Fish Market                          Field
# 145                 Field           Fast Food Restaurant
#
# [124 rows x 12 columns]

# %%
#Cluster 3 for Mumbai
bintang_merged.loc[bintang_merged['Cluster Labels'] == 2, bintang_merged.columns[[2] + list(range(5, bintang_merged.shape[1]))]]
# Out:
#             Area   Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 11  Charni Road   18.951754  72.818369               2             Juice Bar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 11                  Café            Restaurant  Fast Food Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 11         Train Station     Indian Restaurant    Italian Restaurant
#
#    8th Most Common Venue
# 11        Breakfast Spot

# %%
#Cluster 1 for Pune
jdt_merged.loc[jdt_merged['Cluster Labels'] == 0, jdt_merged.columns[[2] + list(range(5, jdt_merged.shape[1]))]]
# Out:
#                                     Area   Latitude  Longitude  \
# 5                                  Pune   18.457955  73.791910
# 10                            Nana Peth   18.520430  73.856744
# 14            Ammunition Factory Khadki   18.564094  73.860245
# 17                         Khadki Bazar   18.568054  73.850869
# 21                       Film Institute   18.512991  73.828631
# 25                              Yerwada   18.552878  73.879637
# 42                           Dukirkline   18.567315  73.926558
# 43                        Vadgaon Sheri   18.552719  73.920817
# 44                              Dhanori   18.583500  73.886488
# 53                      Masulkar Colony   18.633792  73.814336
# 54                      Nehrunagar Pune   18.632669  73.822057
# 56                       Chinchwad East   18.629781  73.799709
# 59                          Range Hills   18.520430  73.856744
# 61                                 Srpf   18.491230  73.909528
# 63                      Khadakwasla R S   18.445183  73.785595
# 68           Kunal Icon Pimple Saudagar   18.593397  73.795888
# 69   Roseland Residency Pimple Saudagar   18.593095  73.794667
# 71                          Sasanenagar   18.491955  73.934512
# 86                            Kasarwadi   18.606087  73.822792
# 87                               Akurdi   18.650484  73.778579
# 90                            Bibvewadi   18.471796  73.867091
# 92                       Salisbury Park   18.492614  73.875720
# 98                                 Afmc   18.504037  73.890096
# 106                          Dhankawadi   18.461621  73.850532
# 115                             N I B M   18.490164  73.951987
# 120                               Warje   18.486473  73.796834
#
#      Cluster Labels  1st Most Common Venue 2nd Most Common Venue  \
# 5                 0                    NaN                   NaN
# 10                0          Historic Site      Department Store
# 14                0                    NaN                   NaN
# 17                0       Department Store  Medical Supply Store
# 21                0                   Café           Snack Place
# 25                0             Donut Shop         Women's Store
# 42                0                    NaN                   NaN
# 43                0  Rajasthani Restaurant          Soccer Field
# 44                0            Bus Station         Women's Store
# 53                0           Dessert Shop           Pizza Place
# 54                0           Hockey Field     Indian Restaurant
# 56                0      Indian Restaurant        Clothing Store
# 59                0          Historic Site      Department Store
# 61                0                    NaN                   NaN
# 63                0            Snack Place     Indian Restaurant
# 68                0                   Café        Sandwich Place
# 69                0         Ice Cream Shop           Pizza Place
# 71                0       Department Store           Pizza Place
# 86                0               Platform     Indian Restaurant
# 87                0            Snack Place     Convenience Store
# 90                0            Snack Place           Pizza Place
# 92                0            Snack Place        Breakfast Spot
# 98                0              Racetrack          Cupcake Shop
# 106               0            Snack Place     Indian Restaurant
# 115               0      Indian Restaurant                 Hotel
# 120               0      Indian Restaurant           Coffee Shop
#
#              3rd Most Common Venue  4th Most Common Venue  \
# 5                              NaN                    NaN
# 10                          Bakery          Women's Store
# 14                             NaN                    NaN
# 17                          Bakery          Women's Store
# 21              Seafood Restaurant  General Entertainment
# 25                       Hotel Bar      Convenience Store
# 42                             NaN                    NaN
# 43                   Women's Store      Food & Drink Shop
# 44                    Concert Hall           Cupcake Shop
# 53              Chinese Restaurant                   Park
# 54              Chinese Restaurant             Restaurant
# 56                   Shopping Mall            Pizza Place
# 59                          Bakery          Women's Store
# 61                             NaN                    NaN
# 63                   Women's Store    Dumpling Restaurant
# 68   Vegetarian / Vegan Restaurant            Pizza Place
# 69                Department Store   Fast Food Restaurant
# 71                            Café   Fast Food Restaurant
# 86            Fast Food Restaurant            Bus Station
# 87               Indian Restaurant   Fast Food Restaurant
# 90                    Dessert Shop         Breakfast Spot
# 92                   Women's Store             Food Court
# 98                   Track Stadium          Women's Store
# 106                     Restaurant    Dumpling Restaurant
# 115           Fast Food Restaurant      Mobile Phone Shop
# 120                    Pizza Place   Fast Food Restaurant
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5                     NaN                   NaN                   NaN
# 10     Falafel Restaurant     Food & Drink Shop                  Food
# 14                    NaN                   NaN                   NaN
# 17     Falafel Restaurant     Food & Drink Shop                  Food
# 21       Department Store          Dessert Shop        Sandwich Place
# 25           Cupcake Shop      Department Store          Dessert Shop
# 42                    NaN                   NaN                   NaN
# 43      Convenience Store          Cupcake Shop      Department Store
# 44       Department Store          Dessert Shop                 Diner
# 53               Tea Room         Women's Store   Dumpling Restaurant
# 54          Women's Store   Dumpling Restaurant           Flea Market
# 56          Jewelry Store             BBQ Joint    Chinese Restaurant
# 59     Falafel Restaurant     Food & Drink Shop                  Food
# 61                    NaN                   NaN                   NaN
# 63                   Food           Flea Market  Fast Food Restaurant
# 68         Ice Cream Shop      Department Store  Fast Food Restaurant
# 69         Sandwich Place    Salon / Barbershop                  Café
# 71         Breakfast Spot         Women's Store            Food Court
# 86          Women's Store     Electronics Store                  Food
# 87             Restaurant   Dumpling Restaurant                  Food
# 90                 Bakery    Falafel Restaurant     Food & Drink Shop
# 92           Cupcake Shop      Department Store          Dessert Shop
# 98    Dumpling Restaurant                  Food           Flea Market
# 106                  Food           Flea Market  Fast Food Restaurant
# 115     Electronics Store     Food & Drink Shop                  Food
# 120         Women's Store   Dumpling Restaurant                  Food
#
#              8th Most Common Venue
# 5                              NaN
# 10                     Flea Market
# 14                             NaN
# 17                     Flea Market
# 21                    Burger Joint
# 25                           Diner
# 42                             NaN
# 43                    Dessert Shop
# 44                      Donut Shop
# 53                     Flea Market
# 54            Fast Food Restaurant
# 56                             Gym
# 59                     Flea Market
# 61                             NaN
# 63              Falafel Restaurant
# 68                     Flea Market
# 69   Vegetarian / Vegan Restaurant
# 71                    Dessert Shop
# 86                     Flea Market
# 87                     Flea Market
# 90                            Food
# 92                           Diner
# 98            Fast Food Restaurant
# 106             Falafel Restaurant
# 115                    Flea Market
# 120                    Flea Market

# %%
#Cluster 2 for Pune
jdt_merged.loc[jdt_merged['Cluster Labels'] == 1, jdt_merged.columns[[2] + list(range(5, jdt_merged.shape[1]))]]
# Out:
#                          Area   Latitude  Longitude  Cluster Labels  \
# 0                    C D A O   18.515806  73.927164               1
# 1               Dr B A Chowk   18.523306  73.869719               1
# 6             Pune New Bazar   18.531229  73.811128               1
# 7            Sachapir Street   18.514758  73.876871               1
# 46              Vishrantwadi   18.572605  73.878208               1
# 49   Shivaji Housing Society   18.531617  73.827439               1
# 62         N D A Khadakwasla   18.461098  73.759112               1
# 65            Indrayaninagar   18.638387  73.845780               1
# 74     Rashtra Bhasha Bhavan   18.515344  73.849752               1
# 78                     C M E   18.519430  73.931855               1
# 85                  Thergaon   18.614113  73.772681               1
# 107                  P C N T   18.657132  73.765907               1
# 109                    N I A   18.520430  73.856744               1
# 110                   Katraj   18.457532  73.867746               1
# 111                 Lohogaon   18.591129  73.918820               1
# 116          Anandnagar Pune   18.477797  73.821321               1
# 117               Karvenagar   18.489759  73.820296               1
#
#     1st Most Common Venue          2nd Most Common Venue  \
# 0             Coffee Shop              Indian Restaurant
# 1      Seafood Restaurant        Comfort Food Restaurant
# 6             Bus Station                  Women's Store
# 7       Indian Restaurant           Fast Food Restaurant
# 46      Indian Restaurant                    Pizza Place
# 49            Coffee Shop                         Lounge
# 62                    NaN                            NaN
# 65      Convenience Store                            Gym
# 74      Indian Restaurant                 Ice Cream Shop
# 78      Indian Restaurant                    Coffee Shop
# 85      Accessories Store  Vegetarian / Vegan Restaurant
# 107     Indian Restaurant                    Snack Place
# 109         Historic Site               Department Store
# 110     Indian Restaurant                    Snack Place
# 111                 Hotel                      Hotel Bar
# 116     Indian Restaurant                    Snack Place
# 117                Bakery                     Food Truck
#
#        3rd Most Common Venue 4th Most Common Venue    5th Most Common Venue  \
# 0                  BBQ Joint         Women's Store        Electronics Store
# 1            Bed & Breakfast        Sandwich Place                   Bakery
# 6               Concert Hall          Cupcake Shop         Department Store
# 7             Breakfast Spot    Chinese Restaurant              Snack Place
# 46   South Indian Restaurant                   Gym                     Café
# 49               IT Services                Bistro                Nightclub
# 62                       NaN                   NaN                      NaN
# 65         Indian Restaurant           Pizza Place                     Food
# 74             Women's Store              Tea Room       Seafood Restaurant
# 78        Chinese Restaurant    Italian Restaurant               Donut Shop
# 85         Mobile Phone Shop       Bed & Breakfast  North Indian Restaurant
# 107                   Bakery      Asian Restaurant                    Diner
# 109                   Bakery         Women's Store       Falafel Restaurant
# 110            Women's Store   Dumpling Restaurant                     Food
# 111        Convenience Store          Cupcake Shop         Department Store
# 116              Pizza Place  Fast Food Restaurant                   Bakery
# 117           Breakfast Spot           Snack Place             Dessert Shop
#
#     6th Most Common Venue 7th Most Common Venue      8th Most Common Venue
# 0       Food & Drink Shop                  Food                Flea Market
# 1             Snack Place    Falafel Restaurant                       Food
# 6            Dessert Shop                 Diner                 Donut Shop
# 7          Ice Cream Shop                Lounge  Indian Chinese Restaurant
# 46         Breakfast Spot          Dessert Shop                      Diner
# 49            Pizza Place             Pool Hall         Chinese Restaurant
# 62                    NaN                   NaN                        NaN
# 65            Flea Market  Fast Food Restaurant         Falafel Restaurant
# 74                   Road            Restaurant                        Bar
# 78         Sandwich Place             Multiplex                        Bar
# 85      Electronics Store                  Food                Flea Market
# 107         Women's Store     Food & Drink Shop                       Food
# 109     Food & Drink Shop                  Food                Flea Market
# 110           Flea Market  Fast Food Restaurant         Falafel Restaurant
# 111          Dessert Shop                 Diner                 Donut Shop
# 116     Electronics Store     Food & Drink Shop                       Food
# 117                 Diner            Donut Shop        Dumpling Restaurant

# %%
#Cluster 3 for Pune
jdt_merged.loc[jdt_merged['Cluster Labels'] == 2, jdt_merged.columns[[2] + list(range(5, jdt_merged.shape[1]))]]
# Out:
#                         Area   Latitude  Longitude  Cluster Labels  \
# 2            Ghorpuri Bazar   18.525956  73.895290               2
# 3               N W College   18.518135  73.855552               2
# 4           Pune Cantt East   18.457955  73.791910               2
# 8              Bajirao Road   18.513342  73.853843               2
# 9                Kapad Ganj   18.514464  73.860143               2
# 11                Pune City   18.457955  73.791910               2
# 12             Raviwar Peth   18.517454  73.861241               2
# 13      Shukrawar Peth Pune   18.508320  73.856700               2
# 15              East Khadki   18.569936  73.850643               2
# 16              H E Factory   18.494207  73.914074               2
# 18                   Khadki   18.569936  73.850643               2
# 19                A R Shala   18.520430  73.856744               2
# 20          Deccan Gymkhana   18.517557  73.841660               2
# 22      Congress House Road   18.522767  73.853129               2
# 23         S S C Exam Board   18.520430  73.856744               2
# 24        Shivajinagar Pune   18.530822  73.847465               2
# 26              Yerwada T S   18.520430  73.856744               2
# 27                Aundh T S   18.520430  73.856744               2
# 28              Ganeshkhind   18.559586  73.817082               2
# 29               Baner Road   18.554973  73.797236               2
# 30               N C L Pune   18.542103  73.811462               2
# 31   Baner Pashan Link Road   18.549111  73.791281               2
# 32     Pride Platinum Baner   18.551745  73.781983               2
# 33             Parvati Gaon   18.497310  73.851095               2
# 34                  Parvati   18.492313  73.854679               2
# 35               Kasba Peth   18.525897  73.861019               2
# 36      Mangalwar Peth Pune   18.524057  73.864694               2
# 37               Rasta Peth   18.517633  73.867123               2
# 38             Dapodi Bazar   18.586696  73.831614               2
# 39                   Dapodi   18.580688  73.833730               2
# ..                       ...        ...        ...             ...
# 79             Airport Pune   18.579343  73.908917               2
# 80              Iaf Station   18.567570  73.926621               2
# 81          Vidyanagar Pune   18.579914  73.894095               2
# 82            Chinchwadgaon   18.629781  73.799709               2
# 83                 Punawale   18.637202  73.745784               2
# 84               Thathawade   18.627597  73.745490               2
# 88               Mundhva Av   18.526343  73.954806               2
# 89                  Mundhva   18.477091  73.890687               2
# 91         Market Yard Pune   18.487654  73.868370               2
# 93                T V Nagar   18.506381  73.914098               2
# 94           Bhusari Colony   18.508212  73.790440               2
# 95     Ex Serviceman Colony   18.511066  73.819676               2
# 96                  Kothrud   18.507399  73.807650               2
# 97              Bhosarigoan   18.620389  73.848189               2
# 99                Wanowarie   18.482890  73.901683               2
# 100          Vadgaon Budruk   18.466658  73.825867               2
# 101            Bhavani Peth   18.511657  73.869918               2
# 102           Ghorpade Peth   18.501947  73.866292               2
# 103            Guruwar Peth   18.506391  73.860284               2
# 104          Swargate Chowk   18.498724  73.858097               2
# 105                Swargate   18.501832  73.863591               2
# 108             Yamunanagar   18.520430  73.856744               2
# 112             Khondhwa Kh   18.477091  73.890687               2
# 113              Kondhwa Bk   18.477091  73.890687               2
# 114              Kondhwa Lh   18.520430  73.856744               2
# 118             Navsahyadri   18.495124  73.828529               2
# 119                   Wakad   18.598943  73.765271               2
# 121             Mohamadwadi   18.470533  73.913578               2
# 122              Rupeenagar   18.674741  73.782908               2
# 123                 Talwade   18.675565  73.782678               2
#
#                1st Most Common Venue           2nd Most Common Venue  \
# 2                               Park                   Women's Store
# 3                  Indian Restaurant                   Historic Site
# 4                                NaN                             NaN
# 8                  Indian Restaurant                    Dessert Shop
# 9                        Flea Market               Indian Restaurant
# 11                               NaN                             NaN
# 12                           Brewery                     Flea Market
# 13     Vegetarian / Vegan Restaurant                    Dessert Shop
# 15                  Department Store            Medical Supply Store
# 16                               NaN                             NaN
# 18                  Department Store            Medical Supply Store
# 19                     Historic Site                Department Store
# 20                 Indian Restaurant   Vegetarian / Vegan Restaurant
# 22                 Indian Restaurant                             Bar
# 23                     Historic Site                Department Store
# 24                 Indian Restaurant                           Hotel
# 26                     Historic Site                Department Store
# 27                     Historic Site                Department Store
# 28                 Electronics Store             Sporting Goods Shop
# 29                 Indian Restaurant                   Women's Store
# 30                               NaN                             NaN
# 31              Fast Food Restaurant                     Coffee Shop
# 32                               NaN                             NaN
# 33                         Bookstore                           Trail
# 34   Southern / Soul Food Restaurant                             Gym
# 35                       Coffee Shop               Indian Restaurant
# 36                           Brewery                  Sandwich Place
# 37           Comfort Food Restaurant            Fast Food Restaurant
# 38                       Coffee Shop                Department Store
# 39                             Hotel                   Train Station
# ..                               ...                             ...
# 79                   Airport Service                       Juice Bar
# 80                               NaN                             NaN
# 81                        Playground         South Indian Restaurant
# 82                 Indian Restaurant                  Clothing Store
# 83                 Mobile Phone Shop                Asian Restaurant
# 84                 Indian Restaurant   Vegetarian / Vegan Restaurant
# 88                 Indian Restaurant                   Women's Store
# 89                        Hookah Bar                       BBQ Joint
# 91                 Indian Restaurant                             Gym
# 93                          Tea Room                             Gym
# 94                 Indian Restaurant                            Café
# 95                       Coffee Shop            Fast Food Restaurant
# 96                    Breakfast Spot                  Sandwich Place
# 97                          Tea Room            Gym / Fitness Center
# 99                              Café                     Coffee Shop
# 100                      Snack Place                   Women's Store
# 101                      Snack Place                   Women's Store
# 102                       Shoe Store                Asian Restaurant
# 103                        Juice Bar                  Ice Cream Shop
# 104                        Hotel Bar  Multicuisine Indian Restaurant
# 105                       Shoe Store                Asian Restaurant
# 108                    Historic Site                Department Store
# 112                       Hookah Bar                       BBQ Joint
# 113                       Hookah Bar                       BBQ Joint
# 114                    Historic Site                Department Store
# 118                      Snack Place                            Café
# 119                             Café                     Pizza Place
# 121              Fried Chicken Joint               Indian Restaurant
# 122                Mobile Phone Shop                   Women's Store
# 123                Mobile Phone Shop                   Women's Store
#
#              3rd Most Common Venue      4th Most Common Venue  \
# 2                     Concert Hall               Cupcake Shop
# 3               Miscellaneous Shop           Department Store
# 4                              NaN                        NaN
# 8    Vegetarian / Vegan Restaurant             Ice Cream Shop
# 9              Arts & Crafts Store    Fruit & Vegetable Store
# 11                             NaN                        NaN
# 12               Indian Restaurant               Neighborhood
# 13                   Jewelry Store          Mobile Phone Shop
# 15                   Women's Store                 Food Truck
# 16                             NaN                        NaN
# 18                   Women's Store                 Food Truck
# 19                          Bakery              Women's Store
# 20            Fast Food Restaurant         Chinese Restaurant
# 22                 Motorcycle Shop              Historic Site
# 23                          Bakery              Women's Store
# 24            Fast Food Restaurant                Pizza Place
# 26                          Bakery              Women's Store
# 27                          Bakery              Women's Store
# 28                      Restaurant                   Bus Line
# 29                          Lounge                        Pub
# 30                             NaN                        NaN
# 31                            Café  Middle Eastern Restaurant
# 32                             NaN                        NaN
# 33               Indian Restaurant          Electronics Store
# 34                  Breakfast Spot             Ice Cream Shop
# 35              Italian Restaurant              Women's Store
# 36                      Donut Shop                     Bakery
# 37               Convenience Store          Indian Restaurant
# 38                    Dessert Shop       Fast Food Restaurant
# 39                    Dessert Shop                  Cafeteria
# ..                             ...                        ...
# 79               Indian Restaurant                Snack Place
# 80                             NaN                        NaN
# 81                     Auto Garage               Cupcake Shop
# 82                   Shopping Mall                Pizza Place
# 83               Electronics Store                 Food Court
# 84                  Sandwich Place              Women's Store
# 88                      Food Truck               Cupcake Shop
# 89                      Restaurant                       Café
# 91               Mobile Phone Shop              Women's Store
# 93                       Bookstore             Ice Cream Shop
# 94                 Motorcycle Shop               Liquor Store
# 95                            Café          Accessories Store
# 96               Indian Restaurant             Ice Cream Shop
# 97                     Flea Market                Chaat Place
# 99                    Burger Joint             Breakfast Spot
# 100                     Food Court          Convenience Store
# 101                     Food Court          Convenience Store
# 102                     Donut Shop                       Bank
# 103                       Pharmacy        Dumpling Restaurant
# 104                 Clothing Store                        Gym
# 105                     Donut Shop                       Bank
# 108                         Bakery              Women's Store
# 112                     Restaurant                       Café
# 113                     Restaurant                       Café
# 114                         Bakery              Women's Store
# 118              Indian Restaurant            Badminton Court
# 119                     Restaurant                        Gym
# 121                     Food Truck               Cupcake Shop
# 122                   Concert Hall               Cupcake Shop
# 123                   Concert Hall               Cupcake Shop
#
#     5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 2        Department Store               Dessert Shop                 Diner
# 3          Ice Cream Shop                     Bakery    Falafel Restaurant
# 4                     NaN                        NaN                   NaN
# 8           Jewelry Store                     Bakery         Women's Store
# 9            Neighborhood              Women's Store     Electronics Store
# 11                    NaN                        NaN                   NaN
# 12             Restaurant                  Juice Bar     Food & Drink Shop
# 13         History Museum          Indian Restaurant              Tea Room
# 15           Cupcake Shop               Dessert Shop                 Diner
# 16                    NaN                        NaN                   NaN
# 18           Cupcake Shop               Dessert Shop                 Diner
# 19     Falafel Restaurant          Food & Drink Shop                  Food
# 20                   Café                      Hotel             Multiplex
# 22   Fast Food Restaurant                    Theater              Tea Room
# 23     Falafel Restaurant          Food & Drink Shop                  Food
# 24             Restaurant                 Donut Shop           Flea Market
# 26     Falafel Restaurant          Food & Drink Shop                  Food
# 27     Falafel Restaurant          Food & Drink Shop                  Food
# 28            Bus Station       Fast Food Restaurant     Mobile Phone Shop
# 29     Punjabi Restaurant    New American Restaurant          Dessert Shop
# 30                    NaN                        NaN                   NaN
# 31     Chinese Restaurant                     Bistro            Restaurant
# 32                    NaN                        NaN                   NaN
# 33             Food Court          Food & Drink Shop                  Food
# 34      Indian Restaurant                Coffee Shop        Clothing Store
# 35    Dumpling Restaurant                       Food           Flea Market
# 36     Seafood Restaurant                       Food           Flea Market
# 37        Bed & Breakfast                  Juice Bar           Snack Place
# 38            Snack Place                 Food Court     Convenience Store
# 39      Electronics Store          Food & Drink Shop                  Food
# ..                    ...                        ...                   ...
# 79             Food Truck       Fast Food Restaurant            Smoke Shop
# 80                    NaN                        NaN                   NaN
# 81       Department Store               Dessert Shop                 Diner
# 82          Jewelry Store                  BBQ Joint    Chinese Restaurant
# 83      Food & Drink Shop                       Food           Flea Market
# 84    Dumpling Restaurant                       Food           Flea Market
# 88       Department Store               Dessert Shop                 Diner
# 89   Fast Food Restaurant  Middle Eastern Restaurant                   Gym
# 91      Food & Drink Shop                       Food           Flea Market
# 93           Cupcake Shop           Department Store          Dessert Shop
# 94      Food & Drink Shop                       Food           Flea Market
# 95                 Bakery                 Playground    Chinese Restaurant
# 96             Food Court                       Café                   Gym
# 97   Karnataka Restaurant                       Food  Fast Food Restaurant
# 99     Falafel Restaurant               Dessert Shop            Food Truck
# 100          Cupcake Shop           Department Store          Dessert Shop
# 101          Cupcake Shop           Department Store          Dessert Shop
# 102  Fast Food Restaurant              Women's Store    Falafel Restaurant
# 103                  Food                Flea Market  Fast Food Restaurant
# 104     Electronics Store                       Food           Flea Market
# 105         Women's Store         Falafel Restaurant     Food & Drink Shop
# 108    Falafel Restaurant          Food & Drink Shop                  Food
# 112  Fast Food Restaurant  Middle Eastern Restaurant                   Gym
# 113  Fast Food Restaurant  Middle Eastern Restaurant                   Gym
# 114    Falafel Restaurant          Food & Drink Shop                  Food
# 118             Juice Bar                       Park              Gym Pool
# 119            Donut Shop                Flea Market  Fast Food Restaurant
# 121      Department Store               Dessert Shop                 Diner
# 122      Department Store               Dessert Shop                 Diner
# 123      Department Store               Dessert Shop                 Diner
#
#     8th Most Common Venue
# 2              Donut Shop
# 3              Food Court
# 4                     NaN
# 8             Snack Place
# 9                    Food
# 11                    NaN
# 12      Electronics Store
# 13         Breakfast Spot
# 15             Donut Shop
# 16                    NaN
# 18             Donut Shop
# 19            Flea Market
# 20            Coffee Shop
# 22              Multiplex
# 23            Flea Market
# 24     Falafel Restaurant
# 26            Flea Market
# 27            Flea Market
# 28    Arts & Crafts Store
# 29         Sandwich Place
# 30                    NaN
# 31   Gym / Fitness Center
# 32                    NaN
# 33            Flea Market
# 34              Multiplex
# 35   Fast Food Restaurant
# 36   Fast Food Restaurant
# 37                   Café
# 38           Cupcake Shop
# 39            Flea Market
# ..                    ...
# 79     Airport Food Court
# 80                    NaN
# 81             Donut Shop
# 82                    Gym
# 83   Fast Food Restaurant
# 84   Fast Food Restaurant
# 88             Donut Shop
# 89            Pizza Place
# 91   Fast Food Restaurant
# 93                  Diner
# 94   Fast Food Restaurant
# 95            Candy Store
# 96      Food & Drink Shop
# 97     Falafel Restaurant
# 99   Fast Food Restaurant
# 100                 Diner
# 101                 Diner
# 102     Food & Drink Shop
# 103    Falafel Restaurant
# 104  Fast Food Restaurant
# 105                  Food
# 108           Flea Market
# 112           Pizza Place
# 113           Pizza Place
# 114           Flea Market
# 118          Tennis Court
# 119    Falafel Restaurant
# 121            Donut Shop
# 122            Donut Shop
# 123            Donut Shop
#
# [81 rows x 12 columns]

# %% [markdown]
# <a id='discussion'></a>
# # Discussion
# <div style="text-align: right">[Top](#toc)</div>
#
# Based on cluster for each cities above, we believe that classification for each cluster can be done better with calculation of venues categories (most common) in each cities. Referring to each cluster, we can't determine clearly what represent in each cluster by using Foursquare - Most Common Venue data.
#
# However, for the sake of this project we assumed each cluster as follow:
# - Cluster 1: Mumbai: Shopping
# - Cluster 2: Mumbai: Mix
# - Cluster 3: Mumbai: Food
# - Cluster 1: Pune: Tourism
# - Cluster 2: Pune: Residential
# - Cluster 3: Pune: Mix
#
# What is lacking at this point is a systematic, quantitative way to identify and distinguish different district and to describe the correlation most common venues as recorded in Foursquare. The reality is however more complex: similar cities might have or might not have similar common venues. A further step in this classification would be to find a method to extract these common venues and integrate the spatial correlations between different of areas or district.
#
# We believe that the classification we propose is an encouraging step towards a quantitative and systematic comparison of the different cities. Further studies are indeed needed in order to relate the data acquired, then observe it to more meaningful and objective results.

# %% [markdown]
# <a id='conclusion'></a>
# # Conclusion
# <div style="text-align: right">[Top](#toc)</div>
#
# Using Foursquare API, we can captured data of common places all around the world. Using it, we refer back to our main objectives, which is to determine;
# - the similarity or dissimilarirty of both cities
# - classification of area located inside the city whether it is residential, tourism places, or others
#
# In conclusion, both cities Mumbai and Pune are the center of attraction among Malaysian. However, to declare both cities are similar or dissimilar base on common venues visited is quite difficult. Both cities is similar in some venues also dissimilar in certain venues. And for classitification based on common venues, again we must have more systematic or quantitative way to identify and declare this. Comparison can be made, but no such method or quantitative data to determine this. We hope in the future, a method to determine it can be establish and explore for references.
#
# Thank you.
#
# by
# Sajesh S Kakkara
# India
# ksajesh@gmail.com
